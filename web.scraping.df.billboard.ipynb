# %% [markdown]
# # Intro to web scraping

# %% [markdown]
# The first step of web scraping is to identify a website and download the html code from it.
#
# Real html from websites tends to be long and a bit too chaotic for a total beginner. Here we will start with a dummy html document and learn the basics of extracting info with beautifulsoup.
#
# - You can learn about Html here https://www.w3schools.com/html/
# - You can use codebeautify to make your html more readable and clean https://codebeautify.org/htmlviewer

# %%
html_doc = """ <!DOCTYPE html><html><head><title>The Dormouse's story</title></head><body><p class="title"><b>The Dormouse's story</b></p><p class="story">Once upon a time there were three little sisters; and their names were<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;and they lived at the bottom of a well.</p><p class="story">...</p></html>"""

# %% [raw]
# html_doc = """
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>The Dormouse's story</title>
#   </head>
#   <body>
#
#     <p class="title">
#       <b>The Dormouse's story</b>
#     </p>
#
#     <p class="story">Once upon a time there were three little sisters; and their names were
#     <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
#     <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
#     <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>
#     ;and they lived at the bottom of a well.
#     </p>
#
#     <p class="story">...</p>
# </html>"""

# %%
html_doc
# Out:
# ' <!DOCTYPE html><html><head><title>The Dormouse\'s story</title></head><body><p class="title"><b>The Dormouse\'s story</b></p><p class="story">Once upon a time there were three little sisters; and their names were<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;and they lived at the bottom of a well.</p><p class="story">...</p></html>'

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### "creating the soup"

# %%
# parse the element
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup
# Out:
#  <!DOCTYPE html>
# <html><head><title>The Dormouse's story</title></head><body><p class="title"><b>The Dormouse's story</b></p><p class="story">Once upon a time there were three little sisters; and their names were<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;and they lived at the bottom of a well.</p><p class="story">...</p></body></html>

# %%
import pprint

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# #### accessing single elements

# %% [markdown]
# We can access html tags by appending to the `soup` a dot `.` and the name of the corresponding tag. In case of having multiple instances of the tag, only the first one will be retrieved.

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.html.body.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# <b> searching using find() function

# %%
soup.find("p").get_text()
# Out:
# "The Dormouse's story"

# %%
# this method only retrieves the first element of the specified tag
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# #### finding all elements of a tag with the powerful find_all()

# %%
p_tags = soup.find_all("p")
p_tags
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %% [markdown]
# To get the `text`from the corresponding html code, we can use the function: get_text()

# %%
for p in p_tags:
    print(p.get_text())
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names wereElsie,Lacie andTillie;and they lived at the bottom of a well.
# ...

# %% [markdown]
# ## Return the 3 names of the sisters

# %%
a_tags = soup.find_all('a')

# %%
for a in a_tags:
    print(a.get_text())
# Out:
# Elsie
# Lacie
# Tillie

# %% [markdown]
# ## Using css selectors
# Another way to find contents using select().
#
# Let's learn first the syntax of css selectors playing this game: https://flukeout.github.io/
#
# Everyone should reach level 6!
#
# https://www.w3schools.com/css/css_howto.asp

# %%
soup.select("a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
for a in soup.select('a'):
    print(a.get_text())
# Out:
# Elsie
# Lacie
# Tillie

# %%
soup.select('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.select("p")[0]
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# using css selector, you can search directly using Css classes!

# %%
soup.select(".title")
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>]

# %% [markdown]
# <b> comparing to find_all() ..

# %%
soup.find_all("a", class_="sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.select("a.sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# <b>  You can searc directly using id attributes

# %%
soup.select("#link2")
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %% [markdown]
# We can combine the `select()` method with other bs4 methods, such as `get_text()`.
#
# `get_text()`, however, can only be applied to single elements, while `select()` might return multiple elements. It's common to iterate through the output of `select()`

# %%
print(soup.select(".story"))
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;and they lived at the bottom of a well.</p>, <p class="story">...</p>]

# %%
for p in soup.select("p.story"):
    print(p.get_text())
# Out:
# Once upon a time there were three little sisters; and their names wereElsie,Lacie andTillie;and they lived at the bottom of a well.
# ...

# %% [markdown]
# Write code to print the following contents (not including the html tags, only human-readable text):
#
# 1. All the "fun facts".
#
# 2. The names of all the places.
#
# 3. The content (name and fact) of all the cities (only cities, not countries!)
#
# 4. The names (not facts!) of all the cities (not countries!)

# %%
geography = """
<!DOCTYPE html>
<html>
<head> Geography</head>
<body>

<div class="city">
  <h2>London</h2>
  <p>London is the most popular tourist destination in the world.</p>
</div>

<div class="city">
  <h2>Paris</h2>
  <p>Paris was originally a Roman City called Lutetia.</p>
</div>

<div class="country">
  <h2>Spain</h2>
  <p>Spain produces 43,8% of all the world's Olive Oil.</p>
</div>

</body>
</html>
"""

# %%
soup = BeautifulSoup(geography, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   Geography
#  </head>
#  <body>
#   <div class="city">
#    <h2>
#     London
#    </h2>
#    <p>
#     London is the most popular tourist destination in the world.
#    </p>
#   </div>
#   <div class="city">
#    <h2>
#     Paris
#    </h2>
#    <p>
#     Paris was originally a Roman City called Lutetia.
#    </p>
#   </div>
#   <div class="country">
#    <h2>
#     Spain
#    </h2>
#    <p>
#     Spain produces 43,8% of all the world's Olive Oil.
#    </p>
#   </div>
#  </body>
# </html>

# %%
# Your code goes here
#Fun facts
fun_facts = soup.find_all("p")
fun_facts
# Out:
# [<p>London is the most popular tourist destination in the world.</p>,
#  <p>Paris was originally a Roman City called Lutetia.</p>,
#  <p>Spain produces 43,8% of all the world's Olive Oil.</p>]

# %%
for p in fun_facts:
    print(p.get_text())
# Out:
# London is the most popular tourist destination in the world.
# Paris was originally a Roman City called Lutetia.
# Spain produces 43,8% of all the world's Olive Oil.

# %%
#Names of all the places
all_places = soup.find_all("h2")
all_places
# Out:
# [<h2>London</h2>, <h2>Paris</h2>, <h2>Spain</h2>]

# %%
for p in all_places:
    print(p.get_text())
# Out:
# London
# Paris
# Spain

# %%
#The content (name and fact) of all the cities (only cities, not countries!)
soup.select(".city")
# Out:
# [<div class="city">
#  <h2>London</h2>
#  <p>London is the most popular tourist destination in the world.</p>
#  </div>,
#  <div class="city">
#  <h2>Paris</h2>
#  <p>Paris was originally a Roman City called Lutetia.</p>
#  </div>]

# %%
for p in soup.select(".city"):
    print(p.get_text())
# Out:
# London
# London is the most popular tourist destination in the world.
#
#
# Paris
# Paris was originally a Roman City called Lutetia.

# %%
#The names (not facts!) of all the cities (not countries!)
for city in soup.select("div.city h2"):
    print(city.get_text())
# Out:
# London
# Paris

# %% [markdown]
# ## Use case:

# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://www.timeout.com/film/best-movies-of-all-time"
requests.get(url)
# Out:
# <Response [200]>

# %% [markdown]
# # <b> using requests package

# %%
# 3. download html with a get request 
response = requests.get(url)

# %%
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-GB"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><link href="/static/images/favicon.ico" rel="icon" sizes="16x16" type="image/x-icon"/><link href="/static/images/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/static/images/favicon-48.png" rel="icon" sizes="48x48" type="image/png"/><link href="/static/images/favicon-180.png" rel="apple-touch-icon" type="image/png"/><title>100 Best Movies of All Time That You Should Watch Immediately</title><meta content="We have ranked the best movies of all time that our film editors say you need to watch. Which movie is your favourite?" name="description"/><link href="https://www.timeout.com/film/best-movies-of-all-time" rel="canonical"/><meta content="max-image-preview:large" name="robots"/><script>window.digitalData = {"pageInstanceID":"web-uk-worldwide.127741-prod","version":"1.0","timestamp":1707736828238,"page":{"pageInfo":{"placeId":1,"sysEnv":"prod","city":"Worldwide","hourOfDay":"11","dayOfWeek":"Monday","version":5,"language":"en","country":"UK","locale":"en-GB","siteId":"uk-worldwide","isOO":"true","reportSuites":"timeoutworldwide","pageID":"127741","author":"Phil de Semlyen, Joshua Rothkopf, Matthew Singer","pageName":"the 100 best movies of all time : feature page","contentTitle":"The 100 best movies of all time","contentID":"content-page-127741","contentType":"feature","siteSection":"the 100 best movies of all time : feature page","destinationURL":"https://www.timeout.com/film/best-movies-of-all-time","publishDate":"2024-02-09T04:09:24Z","createdDate":"2019-05-20T21:08:44+01:00","displayPublishDate":true,"pagination":"","canaryID":"False"},"category":{"primaryCategory":"film (category)","primaryCategoryRepresentation":"Film","subCategory1":"","pageTags":["Film","Categories: Film","Format: Big film list","global kickers: Time In"],"pageType":"feature","nlp":["Night of the Living Dead","Stephen Garrett","Anna Smith","Ian Freer","Joshua Rothkopf","George A. Romero","Dave Calhoun","Phil de Semlyen","Tomris Laffly","Bilge Ebiri","Matthew Singer","Jordan Peele","Peele","Abbey Bender"]},"attributes":{"commercial":{"enabled":false,"type":"","authorOverride":""},"social":{"title":"100 Best Movies of All Time That You Should Watch Immediately","subTitle":"Which movie is your favourite?"},"description":"In case you couldn&rsquo;t tell, we love movies &ndash; and if you&rsquo;re reading this, presumably you do, too. Who doesn&rsquo;t, really? That&rsquo;s not a controversial statement. The controversy happens when you start talking about the greatest movies of all-time. Because while everyone loves getting lost in a film for two-plus hours, not everyone loves the same films. Tastes in cinema vary wildly, of course: one person&rsquo;s Citizen Kane is another&rsquo;s Deuce Bigalow: Male Gigolo, or vice versa. (Hey, it&rsquo;s possible.)&nbsp;&nbsp;\r\nThat can make ranking the best movies ever made a fraught process. But the point of the list you&rsquo;re about to peruse isn&rsquo;t to solidify any sort of canon. It&rsquo;s better to think of it as a roadmap. If you&rsquo;re just beginning to fill in the gaps of your movie knowledge, this is the perfect way to identify the holes. And if you&rsquo;re enough of a cinephile to have seen every movie on here already, it might cause you to rethink your own personal rankings. It&rsquo;s a list that covers a lot of ground: over 100 years, multiple countries, and just about every genre you can imagine, from monolithic blockbusters to treasured cult classics, ridiculous comedies to freaky horror, sweaty-palmed thrillers to eye-popping action flicks. So get exploring &ndash; you may not like everything you see, but we&rsquo;re confident you&rsquo;ll find something that surprises you.\r\nWritten by Abbey Bender, Dave Calhoun, Phil de Semlyen, Bilge Ebiri, Ian Freer, Stephen Garrett, Tomris Laffly, Joshua Rothkopf, Anna Smith and Matthew Singer\r\n ...
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NHG693B');</script><link href="/static/css/main-5e2aeb03a91e51cdda59f8ede08ff4d7.css" rel="stylesheet"/><link href="/static/css/listfeature-c88025cb655edb219a222409ece376a9.css" rel="stylesheet"/><link as="style" href="/static/css/bedrock-2978f17ce5dc2012de0ebc89a4b9fde7.css" id="bedrock" rel="preload"/><link crossorigin="" href="https://cdn.permutive.com" rel="preconnect"/><link as="font" crossorigin="anonymous" href="/static/fonts/roboto-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/static/fonts/roboto-bold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/static/fonts/franklin-gothic-lt-pro-dm-cm.woff2" rel="preload" type="font/woff2"/><link as="image" href="https://media.timeout.com/images/102793667/400/225/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/750/422/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1024/576/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1372/772/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1536/864/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1920/1080/image.jpg" rel="preload"/><script>
#           window.adGlobals = window.adGlobals || {};
#
#           window.adGlobals.gptParams = window.adGlobals.gptParams || {
#             host: 'timeout.uk.worldwide.en',
#             network_code: '5185',
#             zone: 'film',
#             category: 'film',
#             page: 'feature',
#             itemid: 'page-127741',
#             audience: 'default',
#             source: 'Direct',
#             editorial_host: 'Worldwide',
#             canary: 'false',
#             hero_full_width: 'false',
#             prototype: 'false'
#             , kicker: ['time-in']
#
#             , nlp: ['Night of the Living Dead', 'Stephen Garrett', 'Anna Smith', 'Ian Freer', 'Joshua Rothkopf', 'George A. Romero', 'Dave Calhoun', 'Phil de Semlyen', 'Tomris Laffly', 'Bilge Ebiri', 'Matthew Singer', 'Jordan Peele', 'Peele', 'Abbey Bender']
#           }
#         </script><script src="/static/js/store-2fab580a224dda9dbaeb.js"></script><script async="" src="/static/js/cmp-95e95cfb1e13e3347f7e.js"></script><script async="" src="/static/js/permutive-871b990eb66e4f6c1474.js"></script><script async="" src="https://cdn.permutive.com/67cbf6c5-d926-407b-a684-a0606570ff08-web.js"></script><script async="" src="https://micro.rubiconproject.com/prebid/dynamic/11092.js?canary=false&amp;host=timeout.uk.worldwide.en"></script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script defer="" src="/static/js/ads-4299e8347ebd48dcc71b.js"></script><script defer="" src="/static/js/libs-e32bb1f00a37335f840f.js"></script><script defer="" src="/static/js/main-3c388e2b65c5d23c551d.js"></script><meta content="summary_large_image" name="twitter:card"/><meta content="100 Best Movies of All Time That You Should Watch Immediately" name="twitter:title"/><meta content="Which movie is your favourite?" name="twitter:description"/><meta content="https://media.timeout.com/images/102793667/image.jpg" property="twitter:image"/><meta content="100 Best Movies of All Time That You Should Watch Immediately" property="og:title"/><meta content="Which movie is your favourite?" property="og:description"/><meta content="https://www.timeout.com/film/best-movies-of-all-time" property="og:url"/><meta content="https://media.timeout.com/images/102793667/image.jpg" property="og:image"/><meta content="en-GB" property="og:locale"/><meta content="110523762296825" property="fb:app_id"/><meta content="Time Out Worldwide" property="og:site_name"/><meta content="article" property="og:type"/><meta content="108567654280858,1670703719868417,174242829266612,120767178004956,155014857903554,110806252326039,409399439112038,1446189005633181,1640139182938675,726032854137181,127115470664822,199312830102994,277086222458072,225473697480565,176178312421715,260316788252,24247856516,114687728553778,39439020663,425095207624727,167113240025188,87396842402,130436867619222,79807336765,323652267735749,49342614805,364918466158,1658004801141837,920467047965637,297605497404,756469617704922,646556245421580,143754132316142,34127084244,308385419176623,55290780338,127485225400,609582352454281,384475866176,1423947147859126,631789766893061,321104281941901" property="fb:pages"/><meta content="uk-worldwide" name="site"/><meta content="en-GB" name="locale"/><meta content="https://discover.timeout.com/v1" name="discover"/><meta content="https://auth.timeout.com/api/subscribe" name="auth"/><script>window._taboola = window._taboola || [];
#     _taboola.push({article:'auto'});
#     !function (e, f, u, i) {
#       if (!document.getElementById(i)){
#         e.async = 1;
#         e.src = u;
#         e.id = i;
#         f.parentNode.insertBefore(e, f);
#       }
#     }(document.createElement('script'),
#     document.getElementsByTagName('script')[0],
#     '//cdn.taboola.com/libtrc/timeoutmediagroup-timeoutcomen/loader.js',
#     'tb_loader_script');
#     if(window.performance && typeof window.performance.mark == 'function')
#       {window.performance.mark('tbl_ic');}</script><meta content="post" name="parsely-type"/><meta content="100 Best Movies of All Time That You Should Watch Immediately" name="parsely-title"/><meta content="https://www.timeout.com/film/best-movies-of-all-time" name="parsely-link"/><meta content="https://media.timeout.com/images/102793667/image.jpg" name="parsely-image-url"/><meta content="2024-02-08T00:00:00Z" name="parsely-pub-date"/><meta content="Worldwide" name="parsely-section"/><meta content="Phil de Semlyen" name="parsely-author"/><meta content="Joshua Rothkopf" name="parsely-author"/><meta content="Matthew Singer" name="parsely-author"/><meta content="Film, Categories: Film, Format: Big film list, global kickers: Time In" name="parsely-tags"/></head><body data-page-type="feature"><div class="_ad_1elek_1 _ad-skin_1elek_40" data-testid="ad_testID" id="ad-skin-1-9955"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/skin/feature","adContainerId":"ad-skin-1-9955","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[1,1]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"skin"}],"adSenseTags":[],"adSlotGroup":"skin","breakpoints":["xl"],"loadsAutomatically":true}');
#                 </script></div><div class="_ad_1elek_1 _ad-oop_1elek_15" data-testid="ad_testID" id="ad-oop-1-1042"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/oop/feature","adContainerId":"ad-oop-1-1042","isOutOfPage":true,"isRegistered":false,"adSizes":[],"adTags":[{"key":"type","value":"oop"}],"adSenseTags":[],"adSlotGroup":"oop","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><script>window._TO = window._TO || {};
# window._TO.frontendTranslations = window._TO.frontendTranslations || {
# 'JWPLAYER.geoblocking_error': 'This video is not available in your location.'
# }</script><section class="_skipLinks_8n5ih_1" data-testid="skip-links_testID"><a aria-hidden="true" href="#main-container">Go to the content</a><a aria-hidden="true" href="#site-footer">Go to the footer</a></section><div class="_overlay_kzzn5_1" data-component="popup-newsletter" hidden="" id="popup-newsletter"><div class="_popupNewsletterContainer_kzzn5_36" id="popup-newsletter-container"><button class="_closeButton_kzzn5_73" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-close-button"><svg viewbox="0 0 15 15" xmlns="http://www.w3.org/2000/svg"><path d="M9.54594 7.42462L14.8492 2.12132L12.7279 0L7.42462 5.3033L2.12132 0L9.53674e-07 2.12132L5.3033 7.42462L9.53674e-07 12.7279L2.12132 14.8492L7.42462 9.54594L12.7279 14.8492L14.8492 12.7279L9.54594 7.42462Z"></path></svg><span class="_text-hide_v9moj_1">No thanks</span></button><div class="_popupMainContent_kzzn5_66"><div class="_successMessageContainer_kzzn5_22"><p class="_successMessageTitle_kzzn5_115"> Awesome, you're subscribed!</p><p class="_successMessageText_kzzn5_125">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div><form class="_form_kzzn5_108"><p class="_title_kzzn5_114" id="popup-newsletter-title">The best things in life are free.</p><p class="_message_kzzn5_124" id="popup-newsletter-message">Sign up for our email to enjoy your city without spending a thing (as well as some options when you’re feeling flush).</p><label class="_text-hide_v9moj_1" for="popup-newsletter-email">Enter email address</label><div class="_textWrap_kzzn5_139"><p class="_errorMessage_kzzn5_157">Déjà vu! We already have this email. Try another?</p><input class="_textInput_kzzn5_144 _email_kzzn5_177" data-private="lipsum" id="popup-newsletter-email" name="email" placeholder="Enter email address" required="" type="email"/></div><input class="_submitButton_kzzn5_182" type="submit" value="Subscribe now"/></form><a class="_dismissButton_kzzn5_217" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-dismiss-button">No thanks</a><div class="_disclaimer_kzzn5_234" id="popup-newsletter-disclaimer"><p>By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div></div></div><div class="_overlay_kzzn5_1" data-component="popup-gate-newsletter" hidden="" id="popup-gate-newsletter"><div class="_popupNewsletterContainer_kzzn5_36" id="popup-newsletter-container"><button class="_closeButton_kzzn5_73" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-close-button"><svg viewbox="0 0 15 15" xmlns="http://www.w3.org/2000/svg"><path d="M9.54594 7.42462L14.8492 2.12132L12.7279 0L7.42462 5.3033L2.12132 0L9.53674e-07 2.12132L5.3033 7.42462L9.53674e-07 12.7279L2.12132 14.8492L7.42462 9.54594L12.7279 14.8492L14.8492 12.7279L9.54594 7.42462Z"></path></svg><span class="_text-hide_v9moj_1">No thanks</span></button><div class="_popupMainContent_kzzn5_66"><div class="_successMessageContainer_kzzn5_22"><p class="_successMessageTitle_kzzn5_115"> Awesome, you're subscribed!</p><p class="_successMessageText_kzzn5_125">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div><form class="_form_kzzn5_108"><p class="_title_kzzn5_114" id="popup-newsletter-title">Love the mag?</p><p class="_message_kzzn5_124" id="popup-newsletter-message">Our newsletter hand-delivers the best bits to your inbox. Sign up to unlock our digital magazines and also receive the latest news, eve ...
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/head/feature","adContainerId":"ad-head-1-41","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[970,250],[728,90]]},{"viewport":[768,50],"slotSize":[[728,90],[320,100],[300,100],[320,50],[300,50]]},{"viewport":[320,50],"slotSize":[[320,100],[320,50],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[800,0],"sizes":[[970,250],[728,90]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"head"}],"adSenseTags":[],"adSlotGroup":"head","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div><header class="_header_7dcbk_1 _full-width-ui_1elek_111"><div class="_container_18ask_1 _headerOuterContainer_7dcbk_152" data-component="masthead"><div class="_grid_1p4mq_1"><section class="_header_1p4mq_10"><div class="_headerContainer_7dcbk_12"><div class="_content_7dcbk_34"><div class="_left_7dcbk_80"><div class="_sm_7dcbk_130 _navigationDrawerCtaContainer_7dcbk_60"><div class="_container_ty2xw_4" data-testid="navigation-drawer_testID"><input class="_checkbox_ty2xw_1" data-navigation-toggle="true" data-testid="navigation-cta_testID" id="checkbox-navigation-toggle" type="checkbox"/><div class="_overlay_ty2xw_1"></div><label class="_label_ty2xw_1" for="checkbox-navigation-toggle"><a class="_cta_ty2xw_1"><svg viewbox="0 0 24.1 18" xmlns="http://www.w3.org/2000/svg"><path d="M22.832 15.545a1.227 1.227 0 010 2.455H1.227a1.227 1.227 0 110-2.455zm0-7.772a1.227 1.227 0 010 2.454H1.227a1.227 1.227 0 110-2.454zm0-7.773a1.227 1.227 0 010 2.455H1.227a1.227 1.227 0 110-2.455z" fill-rule="evenodd"></path></svg></a><a class="_cta_ty2xw_1 _close_ty2xw_1"><svg viewbox="0 0 22 18" xmlns="http://www.w3.org/2000/svg"><path d="M4.406 17.43c.188.21.422.312.703.312.246 0 .48-.101.7-.312l6.25-6.02 6.25 6.02c.218.21.453.312.699.312a.885.885 0 00.699-.312c.25-.211.375-.426.375-.653 0-.222-.125-.457-.375-.695l-6.25-6.02 6.25-6.019c.25-.238.375-.473.375-.695 0-.227-.125-.442-.375-.653-.215-.238-.441-.36-.676-.36-.23 0-.472.122-.722.36l-6.25 6.02-6.25-6.02c-.25-.238-.493-.36-.723-.36-.234 0-.461.122-.68.36-.246.211-.37.426-.37.653 0 .222.124.457.37.695l6.254 6.02-6.254 6.019c-.246.238-.37.473-.37.695 0 .227.124.442.37.653zm0 0"></path></svg><span class="_text-hide_v9moj_1">Close</span></a></label><div class="_nav_ty2xw_1" data-testid="navigation-menu_testID"><div class="_header_ty2xw_1"><span>Worldwide</span></div><ul class="_ul_ty2xw_1" data-testid="navigation-menu_sections-with-seperator_testID"><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/news" target="_self">News</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/things-to-do" target="_self">Things to Do</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/food-and-drink" target="_self">Food &amp; Drink</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/arts-and-culture" target="_self">Arts &amp; Culture</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/travel" target="_self">Travel</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/movies" target="_self">Movies</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/music" target="_self">Music</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/time-out-market" target="_self">Time Out Market</a></li></ul><div class="_popularCities_ty2xw_1"><input data-animated-chevron-input="true" data-navigation-popular-cities-toggle="true" id="checkbox-navigation-popular-cities-toggle" type="checkbox"/><label class="_popularCiti ...
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/body1/feature","adContainerId":"ad-body-1-4128","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[992,50],"slotSize":[]},{"viewport":[320,50],"slotSize":[[1,1],[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[800,0],"sizes":[[728,90]]},{"minViewPort":[320,50],"sizes":[[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"body1"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"body","breakpoints":["xs","sm"],"loadsAutomatically":true}');
#                 </script></div></div></div></div><div class="_content_17d4d_1" data-component="annotation" data-testid="annotation_testID" id="content"><p><span>In case you couldn’t tell, we love movies – and if you’re reading this, presumably you do, too. Who doesn’t, really? That’s not a controversial statement. The controversy happens when you start talking about the greatest movies of all-time. Because while everyone loves getting lost in a film for two-plus hours, not everyone loves the same films. Tastes in cinema vary wildly, of course: one person’s </span><em><span>Citizen Kane</span></em><span> is another’s </span><em><span>Deuce Bigalow: Male Gigolo</span></em><span>, or vice versa. (Hey, it’s possible.)  </span></p>
# <p><span>That can make ranking the best movies ever made a fraught process. But the point of the list you’re about to peruse isn’t to solidify any sort of canon. It’s better to think of it as a roadmap. If you’re just beginning to fill in the gaps of your movie knowledge, this is the perfect way to identify the holes. And if you’re enough of a cinephile to have seen every movie on here already, it might cause you to rethink your own personal rankings. It’s a list that covers a lot of ground: over 100 years, multiple countries, and just about every genre you can imagine, from monolithic blockbusters to treasured cult classics, ridiculous comedies to freaky horror, sweaty-palmed thrillers to eye-popping action flicks. So get exploring – you may not like everything you see, but we’re confident you’ll find something that surprises you.</span></p>
# <p><em><strong>Written by Abbey Bender, Dave Calhoun, Phil de Semlyen, Bilge Ebiri, Ian Freer, Stephen Garrett, Tomris Laffly, Joshua Rothkopf, Anna Smith </strong>and<strong> Matthew Singer</strong></em></p>
# <p><strong>Recommended:</strong></p>
# <p><strong>🏆 </strong><a href="https://www.timeout.com/film/the-50-most-deserving-oscar-winners-of-all-time"><strong>The 100 greatest horror films ever made<br/></strong></a><strong>🔥 <a href="https://www.timeout.com/film/the-best-movies-of-2023-so-far">The best films of 2023 (so far)</a></strong><a href="https://www.timeout.com/film/the-50-most-deserving-oscar-winners-of-all-time"><strong><br/></strong></a><strong>📺 </strong><a href="https://www.timeout.com/film/best-tv-shows-of-all-time"><strong>The </strong><strong>100 greatest ever TV shows you need to binge</strong></a><a href="https://www.timeout.com/film/best-thriller-movies"><strong><br/></strong></a><strong>🤣 </strong><a href="https://www.timeout.com/film/100-best-comedy-movies"><strong>The best funny films of all-time</strong></a></p></div></div><div class="_landerNewsletter_1c83v_6 _hidden_1c83v_16"><div class="_container_sxeje_1 newsletter_lander" data-component="inline-newsletter" data-newsletter-type="lander" data-testid="inline-newsletter_testID"><div class="row"><div class="panel_form"><div class="_section_heading_sxeje_6"><p class="_form_title_sxeje_30">An email you’ll actually love</p><label class="_label_sxeje_39">Get into a relationship with our newsletter. Discover the best of the city, first.</label></div><form class="_section_form_sxeje_10"><div class="_loading_overlay_sxeje_46 loading_overlay"></div><div class="_zone_input_sxeje_18"><label class="_text-hide_v9moj_1" for="lander-newsletter-email">Enter email address</label><input class="_email_sxeje_77" data-private="lipsum" id="lander-newsletter-email" placeholder="Enter email address" required="" type="email"/><img alt="Loading animation" class="_loading_icon_sxeje_56 loading_icon" src="data:image/gif;base64,..."/><div class="_error_sxeje_63 error">Déjà vu! We already have this email. Try another?</div></div><div class="_zone_submit_sxeje_24"><input class="_submit_sxeje_87" type="submit" value="Subscribe"/></div></form><div class="section_consent"><p class="_consent_sxeje_110">By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div><div class="_panel_success_sxeje_120 panel_success"><p class="_success_title_sxeje_124">🙌 Awesome, you're subscribed!</p><p class="_success_thanks_sxeje_131">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div></div></div></div><div data-component="interscroller"></div><div class="zone _zoneFirst_abr0c_5 _zone_abr0c_1" data-component="lazy-load-zone" data-params='{"zoneId":"8311340","url":"/1/en-GB/pages/127741/zone/8311340?site_id=uk-worldwide&amp;pageNumber=:pageNumber&amp;pageSize=100&amp;gp-web=true"}' data-testid="zone-large-list_testID" data-zone-name="large_list"><h2 class="_h2_1ikgb_1" data-testid="zone-title_testID"><span>Best movies of all time</span></h2><div class="_zoneItems_882m9_1 zoneItems"><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/2001-a-space-odyssey" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455969/380/285/image.webp 380w,https://media.timeout.com/images/105455969/750/562/image.webp 750w,https://media.timeout.com/images/105455969/1024/768/image.webp 1024w,https://media.timeout.com/images/105455969/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455969/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455969/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt= ...
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/2001-a-space-odyssey" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/the-godfather-1972" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455970/380/285/image.webp 380w,https://media.timeout.com/images/105455970/750/562/image.webp 750w,https://media.timeout.com/images/105455970/1024/768/image.webp 1024w,https://media.timeout.com/images/105455970/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455970/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455970/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="The Godfather (1972)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455970/380/285/image.jpg 380w,https://media.timeout.com/images/105455970/750/562/image.jpg 750w,https://media.timeout.com/images/105455970/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455970/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455970/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455970/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455970/750/562/image.jpg" srcset="..." title="The Godfather (1972)" width="750"/></picture></div><figcaption class="_figcaption_1ctb8_1" data-testid="image-credits_testID"><span>Paramount Pictures</span></figcaption></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/the-godfather-1972" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>2.</span> The Godfather (1972)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li><li class="_tag_163gl_1"><span class="_text_163gl_28">Thrillers</span></li></ul></section></div><div class="_summary_kc5qn_21"><p>From the wise guys of <em>Goodfellas</em> to <em>The Sopranos</em>, all crime dynasties that came after<em> The Godfather </em>are descendants of the Corleones: Francis Ford Coppola’s magnum opus is the ultimate patriarch of the Mafia genre. A monumental opening line (“I believe in America”) sets the operatic Mario Puzo adaptation in motion, before Coppola’s epic morphs into a chilling dismantling of the American dream. The corruption-soaked story follows a powerful immigrant family grappling with the paradoxical values of reign and religion; those moral contradictions are crystallized in a legendary baptism sequence, superbly edited in parallel to the murdering of four rivaling dons. With countless iconic details—a horse’s severed head, Marlon Brando’s wheezy voice, Nino Rota’s catchy waltz—<em>The Godfather</em>’s authority lives on.—<em>Tomris Laffly</em></p>
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/the-godfather-1972" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><div class="_adsInline_882m9_6"><div class="_inlineAdWrapper_1elek_65" data-testid="inline-generated-ad_testID"><div class="_inlineAdContainer_1elek_60"><span class="caps xs-block xs-text-10 xs-mb2 xs-text-center _inlineAdHeader_1elek_75">Advertising</span><div class="_inlineAd_1elek_60"><div class="_ad_1elek_1 _ad-list_1elek_54" data-testid="ad_testID" id="ad-list-1-7910"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/list/feature","adContainerId":"ad-list-1-7910","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[728,90],[300,250]]},{"viewport":[320,50],"slotSize":[[1,1],[300,600],[300,250]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[992,0],"sizes":[[728,90],[300,250]]},{"minViewPort":[320,50],"sizes":[[300,600],[300,250]]},{"minViewPort":[320,0],"sizes":[[300,250]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"list"},{"key":"type","value":"list1"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"list","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div></div></div></div><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/citizen-kane" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455971/380/285/image.webp 380w,https://media.timeout.com/images/105455971/750/562/image.webp 750w,https://media.timeout.com/images/105455971/1024/768/image.webp 1024w,https://media.timeout.com/images/105455971/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455971/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455971/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="Citizen Kane (1941)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455971/380/285/image.jpg 380w,https://media.timeout.com/images/105455971/750/562/image.jpg 750w,https://media.timeout.com/images/105455971/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455971/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455971/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455971/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455971/750/562/image.jpg" srcset="..." title="Citizen Kane (1941)" width="750"/></picture></div></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9 _titleNoCredit_kc5qn_197"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/citizen-kane" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>3.</span> Citizen Kane (1941)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li><li class="_tag_163gl_1"><span class="_text_163gl_28">Drama</span></li></ul></section></div><div class="_summary_kc5qn_21"><p><span style="font-weight: 400;">Back in the headlines thanks to </span><a href="https://www.timeout.com/movies/mank"><span style="font-weight: 400;">David Fincher’s brilliantly acerbic making-of drama </span><em><span style="font-weight: 400;">Mank</span></em></a><span style="font-weight: 400;">, </span><em><span style="font-weight: 400;">Citizen Kane</span></em><span style="font-weight: 400;"> always finds a way to renew itself for a new generation of film lovers. For newbies, the journey of its bulldozer of a protagonist – played with inexhaustible force by actor-director-wunderkind Orson Welles – from unloved child to thrusting entrepreneur to press baron to populist feels entirely </span><em><span style="font-weight: 400;">au courant </span></em><span style="font-weight: 400;">(in unconnected news, Donald Trump came out as a superfan). You can bathe in the film’s groundbreaking techniques, like Gregg Toland’s deep-focus photography, or the limitless self-confidence of its staging and its investigation of American capitalism. But it’s also just a damn good story that you definitely don’t need to be a hardened cineaste to enjoy.—<em>Phil de Semlyen</em></span></p>
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/citizen-kane" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/jeanne-dielman-23-quai-du-commerce-1080-bruxelles" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455972/380/285/image.webp 380w,https://media.timeout.com/images/105455972/750/562/image.webp 750w,https://media.timeout.com/images/105455972/1024/768/image.webp 1024w,https://media.timeout.com/images/105455972/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455972/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455972/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455972/380/285/image.jpg 380w,https://media.timeout.com/images/105455972/750/562/image.jpg 750w,https://media.timeout.com/images/105455972/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455972/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455972/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455972/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455972/750/562/image.jpg" srcset="..." title="Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)" width="750"/></picture></div></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9 _titleNoCredit_kc5qn_197"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/jeanne-dielman-23-quai-du-commerce-1080-bruxelles" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>4.</span> Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li></ul></section></div><div class="_summary_kc5qn_21"><p>Long considered a feminist masterpiece, Chantal Akerman’s quietly ruinous portrait of a widow’s daily routine—her chores slowly yielding to a sense of pent-up frustration—should take its rightful place on any all-time list. This is not merely a niche film, but a window onto a universal condition, depicted in a concentrated structuralist style. More hypnotic than you may realize, Akerman’s uninterrupted takes turn the simple acts of dredging veal or cleaning the bathtub into subtle critiques of moviemaking itself. (Pointedly, we never see the sex work Jeanne schedules in her bedroom to make ends meet.) Lulling us into her routine, Akerman and actor Delphine Seyrig create an extraordinary sense of sympathy rarely matched by other movies. <em>Jeanne Dielman</em> represents a total commitment to a woman’s life, hour by hour, minute by minute. And it even has a twist ending.—<em>Joshua Rothkopf</em></p>
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/jeanne-dielman-23-quai-du-commerce-1080-bruxelles" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><div class="_adsInline_882m9_6"><div class="_inlineAdWrapper_1elek_65" data-testid="inline-generated-ad_testID"><div class="_inlineAdContainer_1elek_60"><span class="caps xs-block xs-text-10 xs-mb2 xs-text-center _inlineAdHeader_1elek_75">Advertising</span><div class="_inlineAd_1elek_60"><div class="_ad_1elek_1 _ad-list_1elek_54" data-testid="ad_testID" id="ad-list-2-9660"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/list/feature","adContainerId":"ad-list-2-9660","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[728,90],[300,250]]},{"viewport":[320,50],"slotSize":[[1,1],[300,600],[300,250]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[992,0],"sizes":[[728,90],[300,250]]},{"minViewPort":[320,50],"sizes":[[300,600],[300,250]]},{"minViewPort":[320,0],"sizes":[[300,250]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"list"},{"key":"type","value":"list2"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"list","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div></div></div></div><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/raiders-of-the-lost-ark" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455973/380/285/image.webp 380w,https://media.timeout.com/images/105455973/750/562/image.webp 750w,https://media.timeout.com/images/105455973/1024/768/image.webp 1024w,https://media.timeout.com/images/105455973/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455973/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455973/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="Raiders of the Lost Ark (1981)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455973/380/285/image.jpg 380w,https://media.timeout.com/images/105455973/750/562/image.jpg 750w,https://media.timeout.com/images/105455973/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455973/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455973/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455973/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455973/750/562/image.jpg" srcset="..." title="Raiders of the Lost Ark (1981)" width="750"/></picture></div></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9 _titleNoCredit_kc5qn_197"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/raiders-of-the-lost-ark" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>5.</span> Raiders of the Lost Ark (1981)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li><li class="_tag_163gl_1"><span class="_text_163gl_28">Action and adventure</span></li></ul></section></div><div class="_summary_kc5qn_21"><p>Starting with a dissolve from the Paramount logo and ending in a warehouse inspired by <em>Citizen Kane</em>, <em>Raiders of the Lost Ark</em> celebrates what movies can do more joyously than any other film. Intricately designed as a tribute to the craft, Steven Spielberg’s funnest blockbuster has it all: rolling boulders, a barroom brawl, a sparky heroine (Karen Allen) who can hold her liquor and lose her temper, a treacherous monkey, a champagne-drinking villain (Paul Freeman), snakes (“Why did it have to be snakes?”), cinema’s greatest truck chase and a barnstorming supernatural finale where heads explode. And it’s all topped off by Harrison Ford’s pitch-perfect Indiana Jones, a model of reluctant but resourceful heroism (look at his face when he shoots that swordsman). In short, it’s cinematic perfection.—<em>Ian Freer</em></p>
# ...
#                 </script></div><div class="_ad_1elek_1 _ad-promo_1elek_143" data-testid="ad_testID" id="ad-promo-2-403"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/promo2/feature","adContainerId":"ad-promo-2-403","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[992,50],"slotSize":[[300,250]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"promo2"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"promo","breakpoints":["md","lg","xl"],"loadsAutomatically":false}');
#                 </script></div></div></div></aside><section class="_full_content_1p4mq_27"><div class="recirc_collection" data-collection-concept-name="time in (kicker)" data-collection-name="Time In" data-component="recirc-collection" data-compound-collection-tag="global kickers: Time In" data-recirculation-auth-token="5e06099f978ea00131e54e8b9bf2df746af97aaf" data-recirculation-url="https://recirculation.timeout.com" data-testid="recirc-collection_testID"><div class="_container_1d38e_1 js_recirc_content hide"><div class="_innerContent_1d38e_5"><p class="_heading_1d38e_11 js_heading">More on Time In</p><ul class="_list_1d38e_18 js_recirc_list_items"></ul><template><li class="_recirc_item_1d38e_24 js_recirc_item"><div class="_recirc__item_wrap_1d38e_152"><article class="_recirc__wrap_1d38e_34 recirc__wrap"><a class="_image_wrapper_1d38e_39 image_wrapper" data-data-layer="[gtm_custom_event]" href="[cta_link]">[image]</a><a class="_recirc_link_1d38e_62 recirc_link" data-data-layer="[gtm_custom_event]" href="[cta_link]"><div class="recirc__text_content"><p class="_recirc_title_1d38e_30 recirc__title">[title]</p></div></a></article></div></li></template></div></div></div><div data-component="taboola-mobile-widget" data-testid="taboola-mobile-widget_testID"><div class="_container_1h0jd_1 _hide_1h0jd_7"><span class="_heading_1h0jd_11">You may also like</span><div id="taboola-mobile-below-article-thumbnails"></div><script>window._taboola = window._taboola || [];
#     _taboola.push({
#       mode: 'alternating-thumbnails-a',
#       container: 'taboola-mobile-below-article-thumbnails',
#       placement: 'Mobile Below Article Thumbnails',
#       target_type: 'mix'
#     });</script></div></div><div data-component="taboola-desktop-widget" data-testid="taboola-desktop-widget_testID"><div class="_container_1q8hq_1 _hide_1q8hq_9"><span class="_heading_1q8hq_13">You may also like</span><div id="taboola-below-article-thumbnails"></div><script>window._taboola = window._taboola || [];
#     _taboola.push({
#         mode: 'alternating-thumbnails-a',
#         container: 'taboola-below-article-thumbnails',
#         placement: 'Below Article Thumbnails',
#         target_type: 'mix'
#     });</script></div></div></section></div><div class="_grid_1p4mq_1 _grid_1c83v_32"><section class="_main_content_1p4mq_7"><div class="jwplayer-placement _container_1yj47_1" data-testid="jwplayer-placement_testID" hidden=""><div class="js-content _content_1yj47_40"><p class="_heading_1yj47_14">Discover Time Out original video</p><p class="js-title _title_1yj47_22"> </p></div></div><div class="_ad_1elek_1" data-testid="ad_testID" id="ad-outstream-1-8232"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/outstream/feature","adContainerId":"ad-outstream-1-8232","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[320,50],"slotSize":[[1,1],"fluid"]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[320,0],"sizes":[[1,1],[640,360],[400,250]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"inline"}],"adSenseTags":[],"adSlotGroup":"outstream","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><div class="_ad_1elek_1 _ad-replace_1elek_11" data-testid="ad_testID" id="ad-replace-1-879"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/replace/feature","adContainerId":"ad-replace-1-879","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[320,50],"slotSize":[[5,5]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[],"adSenseTags":[],"adSlotGroup":"replace","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><div class="_inlineAdWrapper_1elek_65 _inlineAdMobile_1elek_125" data-testid="inline-generated-ad_testID"><div class="_inlineAdContainer_1elek_60"><span class="caps xs-block xs-text-10 xs-mb2 xs-text-center _inlineAdHeader_1elek_75">Advertising</span><div class="_inlineAd_1elek_60"><div class="_ad_1elek_1 _ad-body_1elek_139 _ad-mobile_1elek_28" data-testid="ad_testID" id="ad-body-2-8857"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/body2/feature","adContainerId":"ad-body-2-8857","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[992,50],"slotSize":[]},{"viewport":[320,50],"slotSize":[[1,1],[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[800,0],"sizes":[[728,90]]},{"minViewPort":[320,50],"sizes":[[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"body2"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"body","breakpoints":["xs","sm"],"loadsAutomatically":true}');
#                 </script></div></div></div></div></section><aside class="_side_content_1p4mq_8"></aside></div><div data-component="ecomm-widget-card"></div></main><div data-component="inline-placement" data-inline-strategy="sponsored-listing" data-testid="sponsored-listing_testID"><div class="_ad_1elek_1 _ad-native_1elek_55 _sponsoredListing_ra4zo_1" data-testid="ad_testID" id="ad-native-1-4258"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/native/feature","adContainerId":"ad-native-1-4258","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[320,50],"slotSize":[[1,1],"fluid",[712,360]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"native"}],"adSenseTags":[],"adSlotGroup":"native","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><div class="foo" data-component="native-newsletter" data-testid="native-newsletter_testID"><template><div class="_container_nvs8j_1 newsletter_native"><div class="row"><div class="panel_form"><form class="_section_form_nvs8j_7"><div class="_loading_overlay_nvs8j_28 loading_overlay"></div><div class="_zone_input_nvs8j_15"><label class="_text-hide_v9moj_1" for="native-newsletter-email">Enter email address</label><input class="_email_nvs8j_59" data-private="lipsum" id="native-newsletter-email" placeholder="Enter email address" required="" type="email"/><img alt="Loading animation" class="_loading_icon_nvs8j_38 loading_icon" src="data:image/gif;base64,..."/><div class="_error_nvs8j_45 error">Déjà vu! We already have this email. Try another?</div></div><div class="_zone_submit_nvs8j_21"><input class="_submit_nvs8j_68" type="submit" value="Subscribe now"/></div></form><div class="section_consent"><p class="_consent_nvs8j_92">By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div><div class="_panel_success_nvs8j_102 panel_success"><p class="_success_title_nvs8j_106">🙌 Awesome, you're subscribed!</p><p class="_success_thanks_nvs8j_113">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div></div></div></template></div></div></div><div class="_container_1xvir_1 newsletter_footer _full-width-ui_1elek_111" data-component="footer-newsletter"><div class="_row_1xvir_8"><div class="_panel_form_1xvir_138 panel_form"><div class="_section_heading_1xvir_14"><p class="_form_title_1xvir_23">Get us in your inbox</p><label class="_label_1xvir_31">Sign up to our newsletter for the latest and greatest from your city and beyond</label></div><form class="_section_form_1xvir_18"><div class="_loading_overlay_1xvir_35 loading_overlay"></div><div class="_zone_input_1xvir_58"><label class="_text-hide_v9moj_1" for="footer-newsletter-email">Enter email address</label><input class="_email_1xvir_70" data-private="lipsum" id="footer-newsletter-email" placeholder="Enter email address" required="" type="email"/><img alt="Loading animation" class="_loading_icon_1xvir_45 loading_icon" src="data:image/gif;base64,..."/><div class="_error_1xvir_52 error">Déjà vu! We already have this email. Try another?</div></div><div class="_zone_submit_1xvir_64"><input class="_submit_1xvir_79" type="submit" value="Subscribe now"/></div></form><div class="_section_consent_1xvir_177"><p class="_consent_1xvir_103">By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div><div class="_panel_success_1xvir_113 panel_success"><p class="_success_title_1xvir_117">🙌 Awesome, you're subscribed!</p><p class="_success_thanks_1xvir_124">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div></div></div><div class="_footer_1n2qg_1 _full-width-ui_1elek_111" data-testid="footer_testID" id="site-footer"><div class="_footer_ad_wrap_1n2qg_43" data-component="sticky-footer"><button class="_footer_ad_close_1n2qg_23"><svg viewbox="0 0 22 18" xmlns="http://www.w3.org/2000/svg"><path d="M4.406 17.43c.188.21.422.312.703.312.246 0 .48-.101.7-.312l6.25-6.02 6.25 6.02c.218.21.453.312.699.312a.885.885 0 00.699-.312c.25-.211.375-.426.375-.653 0-.222-.125-.457-.375-.695l-6.25-6.02 6.25-6.019c.25-.238.375-.473.375-.695 0-.227-.125-.442-.375-.653-.215-.238-.441-.36-.676-.36-.23 0-.472.122-.722.36l-6.25 6.02-6.25-6.02c-.25-.238-.493-.36-.723-.36-.234 0-.461.122-.68.36-.246.211-.37.426-.37.653 0 ...
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/foot/feature","adContainerId":"ad-foot-1-123","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[994,250],[970,415],[970,250],[970,90],[940,250],[900,250],[728,90],[320,100],[300,100]]},{"viewport":[768,50],"slotSize":[[728,90],[320,50],[300,100],[300,50]]},{"viewport":[320,50],"slotSize":[[320,100],[320,50],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[992,0],"sizes":[[970,250],[728,90],[320,100],[300,100]]},{"minViewPort":[768,0],"sizes":[[728,90],[320,50],[300,100],[300,50]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,100],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"foot"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"foot","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div></div><div class="_footer_content_1n2qg_7 _container_18ask_1"><div class="_grid_1p4mq_1"><a class="_container_vhroe_1 _brand_link_1n2qg_72" data-testid="brand-link_testID" href="https://www.timeout.com">Time Out</a></div><div class="_container_1oyto_1" data-testid="footer-links_testID"><div class="_content_1oyto_5"><div class="_column_1oyto_24 _columnFollowUs_1oyto_30"></div><div class="_column_1oyto_24"><p class="_title_1oyto_11"><a href="https://www.timeout.com/about" target="_blank"><span>About us</span></a></p><ul class="_list_1oyto_36"><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/latest-news" target="_blank">Press office</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/investors" target="_blank">Investor relations</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/awards" target="_blank">Our awards</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/work-for-time-out" target="_blank">Work for Time Out</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/editorial-guidelines" target="_blank">Editorial guidelines</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/privacy-notice" target="_blank">Privacy notice</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/privacy-notice#CCPA" target="_blank">Do not sell my information</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/cookie-policy" target="_blank">Cookie policy</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/accessibility-statement" target="_blank">Accessibility statement</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/terms-of-use" target="_blank">Terms of use</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://assets.timeout.com/application/pdf/292e5c797496115d6f0ecadcefd3fb18/modern_slavery_statement2019.pdf" target="_blank">Modern slavery statement</a></li><li class="_listItem_1oyto_42 navigation_manage_cookies"><a class="_listLink_1oyto_48" href="" target="">Manage cookies</a></li></ul></div><div class="_column_1oyto_24"><p class="_title_1oyto_11"><a href="https://www.timeout.com/about/contact-us" target="_blank"><span>Contact us</span></a></p><ul class="_list_1oyto_36"><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/commercial-opportunities" target="_blank">Advertising</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeoutmarket.com/" target="_blank">Time Out Market</a></li></ul></div><div class="_column_1oyto_24"><p class="_title_1oyto_11"><span>Time Out Worldwide</span></p><ul class="_list_1oyto_36"><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/about/time-out-destinations" target="_self">All Time Out Locations</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/africa" target="_self">Africa</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/asia" target="_self">Asia</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/europe" target="_self">Europe</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/north-america" target="_self">North America</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/south-america" target="_self">South America</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/south-pacific" target="_self">South Pacific</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/metaverse" target="_self">Metaverse</ ...
# (function(h,o,t,j,a,r){
#     h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#     h._hjSettings={hjid:380860,hjsv:6};
#     a=o.getElementsByTagName('head')[0];
#     r=o.createElement('script');r.async=1;
#     r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#     a.appendChild(r);
# })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');</script><div data-component="gtm-data-layer"></div><script>window._taboola = window._taboola || [];
#     _taboola.push({flush: true});</script></body></html>

# %% [markdown]
# ### HTTP Response status codes
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Status

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
# 4.2. check that the html code looks like it should
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-GB"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><link href="/static/images/favicon.ico" rel="icon" sizes="16x16" type="image/x-icon"/><link href="/static/images/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/static/images/favicon-48.png" rel="icon" sizes="48x48" type="image/png"/><link href="/static/images/favicon-180.png" rel="apple-touch-icon" type="image/png"/><title>100 Best Movies of All Time That You Should Watch Immediately</title><meta content="We have ranked the best movies of all time that our film editors say you need to watch. Which movie is your favourite?" name="description"/><link href="https://www.timeout.com/film/best-movies-of-all-time" rel="canonical"/><meta content="max-image-preview:large" name="robots"/><script>window.digitalData = {"pageInstanceID":"web-uk-worldwide.127741-prod","version":"1.0","timestamp":1707736828238,"page":{"pageInfo":{"placeId":1,"sysEnv":"prod","city":"Worldwide","hourOfDay":"11","dayOfWeek":"Monday","version":5,"language":"en","country":"UK","locale":"en-GB","siteId":"uk-worldwide","isOO":"true","reportSuites":"timeoutworldwide","pageID":"127741","author":"Phil de Semlyen, Joshua Rothkopf, Matthew Singer","pageName":"the 100 best movies of all time : feature page","contentTitle":"The 100 best movies of all time","contentID":"content-page-127741","contentType":"feature","siteSection":"the 100 best movies of all time : feature page","destinationURL":"https://www.timeout.com/film/best-movies-of-all-time","publishDate":"2024-02-09T04:09:24Z","createdDate":"2019-05-20T21:08:44+01:00","displayPublishDate":true,"pagination":"","canaryID":"False"},"category":{"primaryCategory":"film (category)","primaryCategoryRepresentation":"Film","subCategory1":"","pageTags":["Film","Categories: Film","Format: Big film list","global kickers: Time In"],"pageType":"feature","nlp":["Night of the Living Dead","Stephen Garrett","Anna Smith","Ian Freer","Joshua Rothkopf","George A. Romero","Dave Calhoun","Phil de Semlyen","Tomris Laffly","Bilge Ebiri","Matthew Singer","Jordan Peele","Peele","Abbey Bender"]},"attributes":{"commercial":{"enabled":false,"type":"","authorOverride":""},"social":{"title":"100 Best Movies of All Time That You Should Watch Immediately","subTitle":"Which movie is your favourite?"},"description":"In case you couldn&rsquo;t tell, we love movies &ndash; and if you&rsquo;re reading this, presumably you do, too. Who doesn&rsquo;t, really? That&rsquo;s not a controversial statement. The controversy happens when you start talking about the greatest movies of all-time. Because while everyone loves getting lost in a film for two-plus hours, not everyone loves the same films. Tastes in cinema vary wildly, of course: one person&rsquo;s Citizen Kane is another&rsquo;s Deuce Bigalow: Male Gigolo, or vice versa. (Hey, it&rsquo;s possible.)&nbsp;&nbsp;\r\nThat can make ranking the best movies ever made a fraught process. But the point of the list you&rsquo;re about to peruse isn&rsquo;t to solidify any sort of canon. It&rsquo;s better to think of it as a roadmap. If you&rsquo;re just beginning to fill in the gaps of your movie knowledge, this is the perfect way to identify the holes. And if you&rsquo;re enough of a cinephile to have seen every movie on here already, it might cause you to rethink your own personal rankings. It&rsquo;s a list that covers a lot of ground: over 100 years, multiple countries, and just about every genre you can imagine, from monolithic blockbusters to treasured cult classics, ridiculous comedies to freaky horror, sweaty-palmed thrillers to eye-popping action flicks. So get exploring &ndash; you may not like everything you see, but we&rsquo;re confident you&rsquo;ll find something that surprises you.\r\nWritten by Abbey Bender, Dave Calhoun, Phil de Semlyen, Bilge Ebiri, Ian Freer, Stephen Garrett, Tomris Laffly, Joshua Rothkopf, Anna Smith and Matthew Singer\r\n ...
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NHG693B');</script><link href="/static/css/main-5e2aeb03a91e51cdda59f8ede08ff4d7.css" rel="stylesheet"/><link href="/static/css/listfeature-c88025cb655edb219a222409ece376a9.css" rel="stylesheet"/><link as="style" href="/static/css/bedrock-2978f17ce5dc2012de0ebc89a4b9fde7.css" id="bedrock" rel="preload"/><link crossorigin="" href="https://cdn.permutive.com" rel="preconnect"/><link as="font" crossorigin="anonymous" href="/static/fonts/roboto-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/static/fonts/roboto-bold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/static/fonts/franklin-gothic-lt-pro-dm-cm.woff2" rel="preload" type="font/woff2"/><link as="image" href="https://media.timeout.com/images/102793667/400/225/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/750/422/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1024/576/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1372/772/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1536/864/image.jpg" rel="preload"/><link as="image" href="https://media.timeout.com/images/102793667/1920/1080/image.jpg" rel="preload"/><script>
#           window.adGlobals = window.adGlobals || {};
#
#           window.adGlobals.gptParams = window.adGlobals.gptParams || {
#             host: 'timeout.uk.worldwide.en',
#             network_code: '5185',
#             zone: 'film',
#             category: 'film',
#             page: 'feature',
#             itemid: 'page-127741',
#             audience: 'default',
#             source: 'Direct',
#             editorial_host: 'Worldwide',
#             canary: 'false',
#             hero_full_width: 'false',
#             prototype: 'false'
#             , kicker: ['time-in']
#
#             , nlp: ['Night of the Living Dead', 'Stephen Garrett', 'Anna Smith', 'Ian Freer', 'Joshua Rothkopf', 'George A. Romero', 'Dave Calhoun', 'Phil de Semlyen', 'Tomris Laffly', 'Bilge Ebiri', 'Matthew Singer', 'Jordan Peele', 'Peele', 'Abbey Bender']
#           }
#         </script><script src="/static/js/store-2fab580a224dda9dbaeb.js"></script><script async="" src="/static/js/cmp-95e95cfb1e13e3347f7e.js"></script><script async="" src="/static/js/permutive-871b990eb66e4f6c1474.js"></script><script async="" src="https://cdn.permutive.com/67cbf6c5-d926-407b-a684-a0606570ff08-web.js"></script><script async="" src="https://micro.rubiconproject.com/prebid/dynamic/11092.js?canary=false&amp;host=timeout.uk.worldwide.en"></script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script defer="" src="/static/js/ads-4299e8347ebd48dcc71b.js"></script><script defer="" src="/static/js/libs-e32bb1f00a37335f840f.js"></script><script defer="" src="/static/js/main-3c388e2b65c5d23c551d.js"></script><meta content="summary_large_image" name="twitter:card"/><meta content="100 Best Movies of All Time That You Should Watch Immediately" name="twitter:title"/><meta content="Which movie is your favourite?" name="twitter:description"/><meta content="https://media.timeout.com/images/102793667/image.jpg" property="twitter:image"/><meta content="100 Best Movies of All Time That You Should Watch Immediately" property="og:title"/><meta content="Which movie is your favourite?" property="og:description"/><meta content="https://www.timeout.com/film/best-movies-of-all-time" property="og:url"/><meta content="https://media.timeout.com/images/102793667/image.jpg" property="og:image"/><meta content="en-GB" property="og:locale"/><meta content="110523762296825" property="fb:app_id"/><meta content="Time Out Worldwide" property="og:site_name"/><meta content="article" property="og:type"/><meta content="108567654280858,1670703719868417,174242829266612,120767178004956,155014857903554,110806252326039,409399439112038,1446189005633181,1640139182938675,726032854137181,127115470664822,199312830102994,277086222458072,225473697480565,176178312421715,260316788252,24247856516,114687728553778,39439020663,425095207624727,167113240025188,87396842402,130436867619222,79807336765,323652267735749,49342614805,364918466158,1658004801141837,920467047965637,297605497404,756469617704922,646556245421580,143754132316142,34127084244,308385419176623,55290780338,127485225400,609582352454281,384475866176,1423947147859126,631789766893061,321104281941901" property="fb:pages"/><meta content="uk-worldwide" name="site"/><meta content="en-GB" name="locale"/><meta content="https://discover.timeout.com/v1" name="discover"/><meta content="https://auth.timeout.com/api/subscribe" name="auth"/><script>window._taboola = window._taboola || [];
#     _taboola.push({article:'auto'});
#     !function (e, f, u, i) {
#       if (!document.getElementById(i)){
#         e.async = 1;
#         e.src = u;
#         e.id = i;
#         f.parentNode.insertBefore(e, f);
#       }
#     }(document.createElement('script'),
#     document.getElementsByTagName('script')[0],
#     '//cdn.taboola.com/libtrc/timeoutmediagroup-timeoutcomen/loader.js',
#     'tb_loader_script');
#     if(window.performance && typeof window.performance.mark == 'function')
#       {window.performance.mark('tbl_ic');}</script><meta content="post" name="parsely-type"/><meta content="100 Best Movies of All Time That You Should Watch Immediately" name="parsely-title"/><meta content="https://www.timeout.com/film/best-movies-of-all-time" name="parsely-link"/><meta content="https://media.timeout.com/images/102793667/image.jpg" name="parsely-image-url"/><meta content="2024-02-08T00:00:00Z" name="parsely-pub-date"/><meta content="Worldwide" name="parsely-section"/><meta content="Phil de Semlyen" name="parsely-author"/><meta content="Joshua Rothkopf" name="parsely-author"/><meta content="Matthew Singer" name="parsely-author"/><meta content="Film, Categories: Film, Format: Big film list, global kickers: Time In" name="parsely-tags"/></head><body data-page-type="feature"><div class="_ad_1elek_1 _ad-skin_1elek_40" data-testid="ad_testID" id="ad-skin-1-9955"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/skin/feature","adContainerId":"ad-skin-1-9955","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[1,1]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"skin"}],"adSenseTags":[],"adSlotGroup":"skin","breakpoints":["xl"],"loadsAutomatically":true}');
#                 </script></div><div class="_ad_1elek_1 _ad-oop_1elek_15" data-testid="ad_testID" id="ad-oop-1-1042"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/oop/feature","adContainerId":"ad-oop-1-1042","isOutOfPage":true,"isRegistered":false,"adSizes":[],"adTags":[{"key":"type","value":"oop"}],"adSenseTags":[],"adSlotGroup":"oop","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><script>window._TO = window._TO || {};
# window._TO.frontendTranslations = window._TO.frontendTranslations || {
# 'JWPLAYER.geoblocking_error': 'This video is not available in your location.'
# }</script><section class="_skipLinks_8n5ih_1" data-testid="skip-links_testID"><a aria-hidden="true" href="#main-container">Go to the content</a><a aria-hidden="true" href="#site-footer">Go to the footer</a></section><div class="_overlay_kzzn5_1" data-component="popup-newsletter" hidden="" id="popup-newsletter"><div class="_popupNewsletterContainer_kzzn5_36" id="popup-newsletter-container"><button class="_closeButton_kzzn5_73" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-close-button"><svg viewbox="0 0 15 15" xmlns="http://www.w3.org/2000/svg"><path d="M9.54594 7.42462L14.8492 2.12132L12.7279 0L7.42462 5.3033L2.12132 0L9.53674e-07 2.12132L5.3033 7.42462L9.53674e-07 12.7279L2.12132 14.8492L7.42462 9.54594L12.7279 14.8492L14.8492 12.7279L9.54594 7.42462Z"></path></svg><span class="_text-hide_v9moj_1">No thanks</span></button><div class="_popupMainContent_kzzn5_66"><div class="_successMessageContainer_kzzn5_22"><p class="_successMessageTitle_kzzn5_115"> Awesome, you're subscribed!</p><p class="_successMessageText_kzzn5_125">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div><form class="_form_kzzn5_108"><p class="_title_kzzn5_114" id="popup-newsletter-title">The best things in life are free.</p><p class="_message_kzzn5_124" id="popup-newsletter-message">Sign up for our email to enjoy your city without spending a thing (as well as some options when you’re feeling flush).</p><label class="_text-hide_v9moj_1" for="popup-newsletter-email">Enter email address</label><div class="_textWrap_kzzn5_139"><p class="_errorMessage_kzzn5_157">Déjà vu! We already have this email. Try another?</p><input class="_textInput_kzzn5_144 _email_kzzn5_177" data-private="lipsum" id="popup-newsletter-email" name="email" placeholder="Enter email address" required="" type="email"/></div><input class="_submitButton_kzzn5_182" type="submit" value="Subscribe now"/></form><a class="_dismissButton_kzzn5_217" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-dismiss-button">No thanks</a><div class="_disclaimer_kzzn5_234" id="popup-newsletter-disclaimer"><p>By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div></div></div><div class="_overlay_kzzn5_1" data-component="popup-gate-newsletter" hidden="" id="popup-gate-newsletter"><div class="_popupNewsletterContainer_kzzn5_36" id="popup-newsletter-container"><button class="_closeButton_kzzn5_73" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-close-button"><svg viewbox="0 0 15 15" xmlns="http://www.w3.org/2000/svg"><path d="M9.54594 7.42462L14.8492 2.12132L12.7279 0L7.42462 5.3033L2.12132 0L9.53674e-07 2.12132L5.3033 7.42462L9.53674e-07 12.7279L2.12132 14.8492L7.42462 9.54594L12.7279 14.8492L14.8492 12.7279L9.54594 7.42462Z"></path></svg><span class="_text-hide_v9moj_1">No thanks</span></button><div class="_popupMainContent_kzzn5_66"><div class="_successMessageContainer_kzzn5_22"><p class="_successMessageTitle_kzzn5_115"> Awesome, you're subscribed!</p><p class="_successMessageText_kzzn5_125">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div><form class="_form_kzzn5_108"><p class="_title_kzzn5_114" id="popup-newsletter-title">Love the mag?</p><p class="_message_kzzn5_124" id="popup-newsletter-message">Our newsletter hand-delivers the best bits to your inbox. Sign up to unlock our digital magazines and also receive the latest news, eve ...
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/head/feature","adContainerId":"ad-head-1-41","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[970,250],[728,90]]},{"viewport":[768,50],"slotSize":[[728,90],[320,100],[300,100],[320,50],[300,50]]},{"viewport":[320,50],"slotSize":[[320,100],[320,50],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[800,0],"sizes":[[970,250],[728,90]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"head"}],"adSenseTags":[],"adSlotGroup":"head","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div><header class="_header_7dcbk_1 _full-width-ui_1elek_111"><div class="_container_18ask_1 _headerOuterContainer_7dcbk_152" data-component="masthead"><div class="_grid_1p4mq_1"><section class="_header_1p4mq_10"><div class="_headerContainer_7dcbk_12"><div class="_content_7dcbk_34"><div class="_left_7dcbk_80"><div class="_sm_7dcbk_130 _navigationDrawerCtaContainer_7dcbk_60"><div class="_container_ty2xw_4" data-testid="navigation-drawer_testID"><input class="_checkbox_ty2xw_1" data-navigation-toggle="true" data-testid="navigation-cta_testID" id="checkbox-navigation-toggle" type="checkbox"/><div class="_overlay_ty2xw_1"></div><label class="_label_ty2xw_1" for="checkbox-navigation-toggle"><a class="_cta_ty2xw_1"><svg viewbox="0 0 24.1 18" xmlns="http://www.w3.org/2000/svg"><path d="M22.832 15.545a1.227 1.227 0 010 2.455H1.227a1.227 1.227 0 110-2.455zm0-7.772a1.227 1.227 0 010 2.454H1.227a1.227 1.227 0 110-2.454zm0-7.773a1.227 1.227 0 010 2.455H1.227a1.227 1.227 0 110-2.455z" fill-rule="evenodd"></path></svg></a><a class="_cta_ty2xw_1 _close_ty2xw_1"><svg viewbox="0 0 22 18" xmlns="http://www.w3.org/2000/svg"><path d="M4.406 17.43c.188.21.422.312.703.312.246 0 .48-.101.7-.312l6.25-6.02 6.25 6.02c.218.21.453.312.699.312a.885.885 0 00.699-.312c.25-.211.375-.426.375-.653 0-.222-.125-.457-.375-.695l-6.25-6.02 6.25-6.019c.25-.238.375-.473.375-.695 0-.227-.125-.442-.375-.653-.215-.238-.441-.36-.676-.36-.23 0-.472.122-.722.36l-6.25 6.02-6.25-6.02c-.25-.238-.493-.36-.723-.36-.234 0-.461.122-.68.36-.246.211-.37.426-.37.653 0 .222.124.457.37.695l6.254 6.02-6.254 6.019c-.246.238-.37.473-.37.695 0 .227.124.442.37.653zm0 0"></path></svg><span class="_text-hide_v9moj_1">Close</span></a></label><div class="_nav_ty2xw_1" data-testid="navigation-menu_testID"><div class="_header_ty2xw_1"><span>Worldwide</span></div><ul class="_ul_ty2xw_1" data-testid="navigation-menu_sections-with-seperator_testID"><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/news" target="_self">News</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/things-to-do" target="_self">Things to Do</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/food-and-drink" target="_self">Food &amp; Drink</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/arts-and-culture" target="_self">Arts &amp; Culture</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/travel" target="_self">Travel</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/movies" target="_self">Movies</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/music" target="_self">Music</a></li><li class="_item_ty2xw_1"><a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/time-out-market" target="_self">Time Out Market</a></li></ul><div class="_popularCities_ty2xw_1"><input data-animated-chevron-input="true" data-navigation-popular-cities-toggle="true" id="checkbox-navigation-popular-cities-toggle" type="checkbox"/><label class="_popularCiti ...
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/body1/feature","adContainerId":"ad-body-1-4128","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[992,50],"slotSize":[]},{"viewport":[320,50],"slotSize":[[1,1],[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[800,0],"sizes":[[728,90]]},{"minViewPort":[320,50],"sizes":[[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"body1"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"body","breakpoints":["xs","sm"],"loadsAutomatically":true}');
#                 </script></div></div></div></div><div class="_content_17d4d_1" data-component="annotation" data-testid="annotation_testID" id="content"><p><span>In case you couldn’t tell, we love movies – and if you’re reading this, presumably you do, too. Who doesn’t, really? That’s not a controversial statement. The controversy happens when you start talking about the greatest movies of all-time. Because while everyone loves getting lost in a film for two-plus hours, not everyone loves the same films. Tastes in cinema vary wildly, of course: one person’s </span><em><span>Citizen Kane</span></em><span> is another’s </span><em><span>Deuce Bigalow: Male Gigolo</span></em><span>, or vice versa. (Hey, it’s possible.)  </span></p>
# <p><span>That can make ranking the best movies ever made a fraught process. But the point of the list you’re about to peruse isn’t to solidify any sort of canon. It’s better to think of it as a roadmap. If you’re just beginning to fill in the gaps of your movie knowledge, this is the perfect way to identify the holes. And if you’re enough of a cinephile to have seen every movie on here already, it might cause you to rethink your own personal rankings. It’s a list that covers a lot of ground: over 100 years, multiple countries, and just about every genre you can imagine, from monolithic blockbusters to treasured cult classics, ridiculous comedies to freaky horror, sweaty-palmed thrillers to eye-popping action flicks. So get exploring – you may not like everything you see, but we’re confident you’ll find something that surprises you.</span></p>
# <p><em><strong>Written by Abbey Bender, Dave Calhoun, Phil de Semlyen, Bilge Ebiri, Ian Freer, Stephen Garrett, Tomris Laffly, Joshua Rothkopf, Anna Smith </strong>and<strong> Matthew Singer</strong></em></p>
# <p><strong>Recommended:</strong></p>
# <p><strong>🏆 </strong><a href="https://www.timeout.com/film/the-50-most-deserving-oscar-winners-of-all-time"><strong>The 100 greatest horror films ever made<br/></strong></a><strong>🔥 <a href="https://www.timeout.com/film/the-best-movies-of-2023-so-far">The best films of 2023 (so far)</a></strong><a href="https://www.timeout.com/film/the-50-most-deserving-oscar-winners-of-all-time"><strong><br/></strong></a><strong>📺 </strong><a href="https://www.timeout.com/film/best-tv-shows-of-all-time"><strong>The </strong><strong>100 greatest ever TV shows you need to binge</strong></a><a href="https://www.timeout.com/film/best-thriller-movies"><strong><br/></strong></a><strong>🤣 </strong><a href="https://www.timeout.com/film/100-best-comedy-movies"><strong>The best funny films of all-time</strong></a></p></div></div><div class="_landerNewsletter_1c83v_6 _hidden_1c83v_16"><div class="_container_sxeje_1 newsletter_lander" data-component="inline-newsletter" data-newsletter-type="lander" data-testid="inline-newsletter_testID"><div class="row"><div class="panel_form"><div class="_section_heading_sxeje_6"><p class="_form_title_sxeje_30">An email you’ll actually love</p><label class="_label_sxeje_39">Get into a relationship with our newsletter. Discover the best of the city, first.</label></div><form class="_section_form_sxeje_10"><div class="_loading_overlay_sxeje_46 loading_overlay"></div><div class="_zone_input_sxeje_18"><label class="_text-hide_v9moj_1" for="lander-newsletter-email">Enter email address</label><input class="_email_sxeje_77" data-private="lipsum" id="lander-newsletter-email" placeholder="Enter email address" required="" type="email"/><img alt="Loading animation" class="_loading_icon_sxeje_56 loading_icon" src="data:image/gif;base64,..."/><div class="_error_sxeje_63 error">Déjà vu! We already have this email. Try another?</div></div><div class="_zone_submit_sxeje_24"><input class="_submit_sxeje_87" type="submit" value="Subscribe"/></div></form><div class="section_consent"><p class="_consent_sxeje_110">By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div><div class="_panel_success_sxeje_120 panel_success"><p class="_success_title_sxeje_124">🙌 Awesome, you're subscribed!</p><p class="_success_thanks_sxeje_131">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div></div></div></div><div data-component="interscroller"></div><div class="zone _zoneFirst_abr0c_5 _zone_abr0c_1" data-component="lazy-load-zone" data-params='{"zoneId":"8311340","url":"/1/en-GB/pages/127741/zone/8311340?site_id=uk-worldwide&amp;pageNumber=:pageNumber&amp;pageSize=100&amp;gp-web=true"}' data-testid="zone-large-list_testID" data-zone-name="large_list"><h2 class="_h2_1ikgb_1" data-testid="zone-title_testID"><span>Best movies of all time</span></h2><div class="_zoneItems_882m9_1 zoneItems"><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/2001-a-space-odyssey" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455969/380/285/image.webp 380w,https://media.timeout.com/images/105455969/750/562/image.webp 750w,https://media.timeout.com/images/105455969/1024/768/image.webp 1024w,https://media.timeout.com/images/105455969/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455969/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455969/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt= ...
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/2001-a-space-odyssey" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/the-godfather-1972" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455970/380/285/image.webp 380w,https://media.timeout.com/images/105455970/750/562/image.webp 750w,https://media.timeout.com/images/105455970/1024/768/image.webp 1024w,https://media.timeout.com/images/105455970/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455970/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455970/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="The Godfather (1972)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455970/380/285/image.jpg 380w,https://media.timeout.com/images/105455970/750/562/image.jpg 750w,https://media.timeout.com/images/105455970/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455970/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455970/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455970/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455970/750/562/image.jpg" srcset="..." title="The Godfather (1972)" width="750"/></picture></div><figcaption class="_figcaption_1ctb8_1" data-testid="image-credits_testID"><span>Paramount Pictures</span></figcaption></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/the-godfather-1972" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>2.</span> The Godfather (1972)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li><li class="_tag_163gl_1"><span class="_text_163gl_28">Thrillers</span></li></ul></section></div><div class="_summary_kc5qn_21"><p>From the wise guys of <em>Goodfellas</em> to <em>The Sopranos</em>, all crime dynasties that came after<em> The Godfather </em>are descendants of the Corleones: Francis Ford Coppola’s magnum opus is the ultimate patriarch of the Mafia genre. A monumental opening line (“I believe in America”) sets the operatic Mario Puzo adaptation in motion, before Coppola’s epic morphs into a chilling dismantling of the American dream. The corruption-soaked story follows a powerful immigrant family grappling with the paradoxical values of reign and religion; those moral contradictions are crystallized in a legendary baptism sequence, superbly edited in parallel to the murdering of four rivaling dons. With countless iconic details—a horse’s severed head, Marlon Brando’s wheezy voice, Nino Rota’s catchy waltz—<em>The Godfather</em>’s authority lives on.—<em>Tomris Laffly</em></p>
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/the-godfather-1972" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><div class="_adsInline_882m9_6"><div class="_inlineAdWrapper_1elek_65" data-testid="inline-generated-ad_testID"><div class="_inlineAdContainer_1elek_60"><span class="caps xs-block xs-text-10 xs-mb2 xs-text-center _inlineAdHeader_1elek_75">Advertising</span><div class="_inlineAd_1elek_60"><div class="_ad_1elek_1 _ad-list_1elek_54" data-testid="ad_testID" id="ad-list-1-7910"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/list/feature","adContainerId":"ad-list-1-7910","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[728,90],[300,250]]},{"viewport":[320,50],"slotSize":[[1,1],[300,600],[300,250]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[992,0],"sizes":[[728,90],[300,250]]},{"minViewPort":[320,50],"sizes":[[300,600],[300,250]]},{"minViewPort":[320,0],"sizes":[[300,250]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"list"},{"key":"type","value":"list1"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"list","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div></div></div></div><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/citizen-kane" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455971/380/285/image.webp 380w,https://media.timeout.com/images/105455971/750/562/image.webp 750w,https://media.timeout.com/images/105455971/1024/768/image.webp 1024w,https://media.timeout.com/images/105455971/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455971/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455971/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="Citizen Kane (1941)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455971/380/285/image.jpg 380w,https://media.timeout.com/images/105455971/750/562/image.jpg 750w,https://media.timeout.com/images/105455971/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455971/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455971/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455971/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455971/750/562/image.jpg" srcset="..." title="Citizen Kane (1941)" width="750"/></picture></div></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9 _titleNoCredit_kc5qn_197"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/citizen-kane" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>3.</span> Citizen Kane (1941)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li><li class="_tag_163gl_1"><span class="_text_163gl_28">Drama</span></li></ul></section></div><div class="_summary_kc5qn_21"><p><span style="font-weight: 400;">Back in the headlines thanks to </span><a href="https://www.timeout.com/movies/mank"><span style="font-weight: 400;">David Fincher’s brilliantly acerbic making-of drama </span><em><span style="font-weight: 400;">Mank</span></em></a><span style="font-weight: 400;">, </span><em><span style="font-weight: 400;">Citizen Kane</span></em><span style="font-weight: 400;"> always finds a way to renew itself for a new generation of film lovers. For newbies, the journey of its bulldozer of a protagonist – played with inexhaustible force by actor-director-wunderkind Orson Welles – from unloved child to thrusting entrepreneur to press baron to populist feels entirely </span><em><span style="font-weight: 400;">au courant </span></em><span style="font-weight: 400;">(in unconnected news, Donald Trump came out as a superfan). You can bathe in the film’s groundbreaking techniques, like Gregg Toland’s deep-focus photography, or the limitless self-confidence of its staging and its investigation of American capitalism. But it’s also just a damn good story that you definitely don’t need to be a hardened cineaste to enjoy.—<em>Phil de Semlyen</em></span></p>
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/citizen-kane" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/jeanne-dielman-23-quai-du-commerce-1080-bruxelles" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455972/380/285/image.webp 380w,https://media.timeout.com/images/105455972/750/562/image.webp 750w,https://media.timeout.com/images/105455972/1024/768/image.webp 1024w,https://media.timeout.com/images/105455972/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455972/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455972/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455972/380/285/image.jpg 380w,https://media.timeout.com/images/105455972/750/562/image.jpg 750w,https://media.timeout.com/images/105455972/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455972/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455972/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455972/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455972/750/562/image.jpg" srcset="..." title="Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)" width="750"/></picture></div></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9 _titleNoCredit_kc5qn_197"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/jeanne-dielman-23-quai-du-commerce-1080-bruxelles" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>4.</span> Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li></ul></section></div><div class="_summary_kc5qn_21"><p>Long considered a feminist masterpiece, Chantal Akerman’s quietly ruinous portrait of a widow’s daily routine—her chores slowly yielding to a sense of pent-up frustration—should take its rightful place on any all-time list. This is not merely a niche film, but a window onto a universal condition, depicted in a concentrated structuralist style. More hypnotic than you may realize, Akerman’s uninterrupted takes turn the simple acts of dredging veal or cleaning the bathtub into subtle critiques of moviemaking itself. (Pointedly, we never see the sex work Jeanne schedules in her bedroom to make ends meet.) Lulling us into her routine, Akerman and actor Delphine Seyrig create an extraordinary sense of sympathy rarely matched by other movies. <em>Jeanne Dielman</em> represents a total commitment to a woman’s life, hour by hour, minute by minute. And it even has a twist ending.—<em>Joshua Rothkopf</em></p>
# <p><strong><em><a href="https://amzn.to/47EA0Aq" rel="nofollow">Watch on Prime Video with a free trial</a></em></strong></p></div><div class="_ctaButtons_kc5qn_43"><div class="_cta_kc5qn_43 _viewMoreCta_kc5qn_105"><a class="_a_12eii_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"read more button"}}' data-testid="view-more-cta_testID" href="/movies/jeanne-dielman-23-quai-du-commerce-1080-bruxelles" rel="" target="_self"><span class="_textContent_12eii_36">Read more</span></a></div></div></div></article><div class="_adsInline_882m9_6"><div class="_inlineAdWrapper_1elek_65" data-testid="inline-generated-ad_testID"><div class="_inlineAdContainer_1elek_60"><span class="caps xs-block xs-text-10 xs-mb2 xs-text-center _inlineAdHeader_1elek_75">Advertising</span><div class="_inlineAd_1elek_60"><div class="_ad_1elek_1 _ad-list_1elek_54" data-testid="ad_testID" id="ad-list-2-9660"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/list/feature","adContainerId":"ad-list-2-9660","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[728,90],[300,250]]},{"viewport":[320,50],"slotSize":[[1,1],[300,600],[300,250]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[992,0],"sizes":[[728,90],[300,250]]},{"minViewPort":[320,50],"sizes":[[300,600],[300,250]]},{"minViewPort":[320,0],"sizes":[[300,250]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"list"},{"key":"type","value":"list2"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"list","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div></div></div></div><article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/raiders-of-the-lost-ark" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><picture><source data-srcset="https://media.timeout.com/images/105455973/380/285/image.webp 380w,https://media.timeout.com/images/105455973/750/562/image.webp 750w,https://media.timeout.com/images/105455973/1024/768/image.webp 1024w,https://media.timeout.com/images/105455973/1372/1029/image.webp 1372w,https://media.timeout.com/images/105455973/1536/1152/image.webp 1536w,https://media.timeout.com/images/105455973/1920/1440/image.webp 1920w" height="562" type="image/webp" width="750"/><img alt="Raiders of the Lost Ark (1981)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455973/380/285/image.jpg 380w,https://media.timeout.com/images/105455973/750/562/image.jpg 750w,https://media.timeout.com/images/105455973/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455973/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455973/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455973/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="https://media.timeout.com/images/105455973/750/562/image.jpg" srcset="..." title="Raiders of the Lost Ark (1981)" width="750"/></picture></div></a></div><div class="articleContent _articleContent_kc5qn_216"><div class="_title_kc5qn_9 _titleNoCredit_kc5qn_197"><a class="" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="/movies/raiders-of-the-lost-ark" rel="" target="_self"><h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>5.</span> Raiders of the Lost Ark (1981)</h3></a></div><div class="_tileTags_kc5qn_44"><section class="_tags_163gl_1" data-testid="tags_testID"><ul class="_tagsList_163gl_5"><li class="_tag_163gl_1"><span class="_text_163gl_28">Film</span></li><li class="_tag_163gl_1"><span class="_text_163gl_28">Action and adventure</span></li></ul></section></div><div class="_summary_kc5qn_21"><p>Starting with a dissolve from the Paramount logo and ending in a warehouse inspired by <em>Citizen Kane</em>, <em>Raiders of the Lost Ark</em> celebrates what movies can do more joyously than any other film. Intricately designed as a tribute to the craft, Steven Spielberg’s funnest blockbuster has it all: rolling boulders, a barroom brawl, a sparky heroine (Karen Allen) who can hold her liquor and lose her temper, a treacherous monkey, a champagne-drinking villain (Paul Freeman), snakes (“Why did it have to be snakes?”), cinema’s greatest truck chase and a barnstorming supernatural finale where heads explode. And it’s all topped off by Harrison Ford’s pitch-perfect Indiana Jones, a model of reluctant but resourceful heroism (look at his face when he shoots that swordsman). In short, it’s cinematic perfection.—<em>Ian Freer</em></p>
# ...
#                 </script></div><div class="_ad_1elek_1 _ad-promo_1elek_143" data-testid="ad_testID" id="ad-promo-2-403"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/promo2/feature","adContainerId":"ad-promo-2-403","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[992,50],"slotSize":[[300,250]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"promo2"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"promo","breakpoints":["md","lg","xl"],"loadsAutomatically":false}');
#                 </script></div></div></div></aside><section class="_full_content_1p4mq_27"><div class="recirc_collection" data-collection-concept-name="time in (kicker)" data-collection-name="Time In" data-component="recirc-collection" data-compound-collection-tag="global kickers: Time In" data-recirculation-auth-token="5e06099f978ea00131e54e8b9bf2df746af97aaf" data-recirculation-url="https://recirculation.timeout.com" data-testid="recirc-collection_testID"><div class="_container_1d38e_1 js_recirc_content hide"><div class="_innerContent_1d38e_5"><p class="_heading_1d38e_11 js_heading">More on Time In</p><ul class="_list_1d38e_18 js_recirc_list_items"></ul><template><li class="_recirc_item_1d38e_24 js_recirc_item"><div class="_recirc__item_wrap_1d38e_152"><article class="_recirc__wrap_1d38e_34 recirc__wrap"><a class="_image_wrapper_1d38e_39 image_wrapper" data-data-layer="[gtm_custom_event]" href="[cta_link]">[image]</a><a class="_recirc_link_1d38e_62 recirc_link" data-data-layer="[gtm_custom_event]" href="[cta_link]"><div class="recirc__text_content"><p class="_recirc_title_1d38e_30 recirc__title">[title]</p></div></a></article></div></li></template></div></div></div><div data-component="taboola-mobile-widget" data-testid="taboola-mobile-widget_testID"><div class="_container_1h0jd_1 _hide_1h0jd_7"><span class="_heading_1h0jd_11">You may also like</span><div id="taboola-mobile-below-article-thumbnails"></div><script>window._taboola = window._taboola || [];
#     _taboola.push({
#       mode: 'alternating-thumbnails-a',
#       container: 'taboola-mobile-below-article-thumbnails',
#       placement: 'Mobile Below Article Thumbnails',
#       target_type: 'mix'
#     });</script></div></div><div data-component="taboola-desktop-widget" data-testid="taboola-desktop-widget_testID"><div class="_container_1q8hq_1 _hide_1q8hq_9"><span class="_heading_1q8hq_13">You may also like</span><div id="taboola-below-article-thumbnails"></div><script>window._taboola = window._taboola || [];
#     _taboola.push({
#         mode: 'alternating-thumbnails-a',
#         container: 'taboola-below-article-thumbnails',
#         placement: 'Below Article Thumbnails',
#         target_type: 'mix'
#     });</script></div></div></section></div><div class="_grid_1p4mq_1 _grid_1c83v_32"><section class="_main_content_1p4mq_7"><div class="jwplayer-placement _container_1yj47_1" data-testid="jwplayer-placement_testID" hidden=""><div class="js-content _content_1yj47_40"><p class="_heading_1yj47_14">Discover Time Out original video</p><p class="js-title _title_1yj47_22"> </p></div></div><div class="_ad_1elek_1" data-testid="ad_testID" id="ad-outstream-1-8232"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/outstream/feature","adContainerId":"ad-outstream-1-8232","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[320,50],"slotSize":[[1,1],"fluid"]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[320,0],"sizes":[[1,1],[640,360],[400,250]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"inline"}],"adSenseTags":[],"adSlotGroup":"outstream","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><div class="_ad_1elek_1 _ad-replace_1elek_11" data-testid="ad_testID" id="ad-replace-1-879"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/replace/feature","adContainerId":"ad-replace-1-879","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[320,50],"slotSize":[[5,5]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[],"adSenseTags":[],"adSlotGroup":"replace","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><div class="_inlineAdWrapper_1elek_65 _inlineAdMobile_1elek_125" data-testid="inline-generated-ad_testID"><div class="_inlineAdContainer_1elek_60"><span class="caps xs-block xs-text-10 xs-mb2 xs-text-center _inlineAdHeader_1elek_75">Advertising</span><div class="_inlineAd_1elek_60"><div class="_ad_1elek_1 _ad-body_1elek_139 _ad-mobile_1elek_28" data-testid="ad_testID" id="ad-body-2-8857"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/body2/feature","adContainerId":"ad-body-2-8857","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[992,50],"slotSize":[]},{"viewport":[320,50],"slotSize":[[1,1],[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[800,0],"sizes":[[728,90]]},{"minViewPort":[320,50],"sizes":[[320,100],[320,50],[300,600],[300,250],[300,100],[300,50]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"body2"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"body","breakpoints":["xs","sm"],"loadsAutomatically":true}');
#                 </script></div></div></div></div></section><aside class="_side_content_1p4mq_8"></aside></div><div data-component="ecomm-widget-card"></div></main><div data-component="inline-placement" data-inline-strategy="sponsored-listing" data-testid="sponsored-listing_testID"><div class="_ad_1elek_1 _ad-native_1elek_55 _sponsoredListing_ra4zo_1" data-testid="ad_testID" id="ad-native-1-4258"><script>
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/native/feature","adContainerId":"ad-native-1-4258","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[320,50],"slotSize":[[1,1],"fluid",[712,360]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"native"}],"adSenseTags":[],"adSlotGroup":"native","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div><div class="foo" data-component="native-newsletter" data-testid="native-newsletter_testID"><template><div class="_container_nvs8j_1 newsletter_native"><div class="row"><div class="panel_form"><form class="_section_form_nvs8j_7"><div class="_loading_overlay_nvs8j_28 loading_overlay"></div><div class="_zone_input_nvs8j_15"><label class="_text-hide_v9moj_1" for="native-newsletter-email">Enter email address</label><input class="_email_nvs8j_59" data-private="lipsum" id="native-newsletter-email" placeholder="Enter email address" required="" type="email"/><img alt="Loading animation" class="_loading_icon_nvs8j_38 loading_icon" src="data:image/gif;base64,..."/><div class="_error_nvs8j_45 error">Déjà vu! We already have this email. Try another?</div></div><div class="_zone_submit_nvs8j_21"><input class="_submit_nvs8j_68" type="submit" value="Subscribe now"/></div></form><div class="section_consent"><p class="_consent_nvs8j_92">By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div><div class="_panel_success_nvs8j_102 panel_success"><p class="_success_title_nvs8j_106">🙌 Awesome, you're subscribed!</p><p class="_success_thanks_nvs8j_113">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div></div></div></template></div></div></div><div class="_container_1xvir_1 newsletter_footer _full-width-ui_1elek_111" data-component="footer-newsletter"><div class="_row_1xvir_8"><div class="_panel_form_1xvir_138 panel_form"><div class="_section_heading_1xvir_14"><p class="_form_title_1xvir_23">Get us in your inbox</p><label class="_label_1xvir_31">Sign up to our newsletter for the latest and greatest from your city and beyond</label></div><form class="_section_form_1xvir_18"><div class="_loading_overlay_1xvir_35 loading_overlay"></div><div class="_zone_input_1xvir_58"><label class="_text-hide_v9moj_1" for="footer-newsletter-email">Enter email address</label><input class="_email_1xvir_70" data-private="lipsum" id="footer-newsletter-email" placeholder="Enter email address" required="" type="email"/><img alt="Loading animation" class="_loading_icon_1xvir_45 loading_icon" src="data:image/gif;base64,..."/><div class="_error_1xvir_52 error">Déjà vu! We already have this email. Try another?</div></div><div class="_zone_submit_1xvir_64"><input class="_submit_1xvir_79" type="submit" value="Subscribe now"/></div></form><div class="_section_consent_1xvir_177"><p class="_consent_1xvir_103">By entering your email address you agree to our <a href="https://www.timeout.com/terms-of-use" target="_blank">Terms of Use</a> and <a href="https://www.timeout.com/privacy-notice" target="_blank">Privacy Policy</a> and consent to receive emails from Time Out about news, events, offers and partner promotions.</p></div></div><div class="_panel_success_1xvir_113 panel_success"><p class="_success_title_1xvir_117">🙌 Awesome, you're subscribed!</p><p class="_success_thanks_1xvir_124">Thanks for subscribing! Look out for your first newsletter in your inbox soon!</p></div></div></div><div class="_footer_1n2qg_1 _full-width-ui_1elek_111" data-testid="footer_testID" id="site-footer"><div class="_footer_ad_wrap_1n2qg_43" data-component="sticky-footer"><button class="_footer_ad_close_1n2qg_23"><svg viewbox="0 0 22 18" xmlns="http://www.w3.org/2000/svg"><path d="M4.406 17.43c.188.21.422.312.703.312.246 0 .48-.101.7-.312l6.25-6.02 6.25 6.02c.218.21.453.312.699.312a.885.885 0 00.699-.312c.25-.211.375-.426.375-.653 0-.222-.125-.457-.375-.695l-6.25-6.02 6.25-6.019c.25-.238.375-.473.375-.695 0-.227-.125-.442-.375-.653-.215-.238-.441-.36-.676-.36-.23 0-.472.122-.722.36l-6.25 6.02-6.25-6.02c-.25-.238-.493-.36-.723-.36-.234 0-.461.122-.68.36-.246.211-.37.426-.37.653 0 ...
#                     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/foot/feature","adContainerId":"ad-foot-1-123","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[994,250],[970,415],[970,250],[970,90],[940,250],[900,250],[728,90],[320,100],[300,100]]},{"viewport":[768,50],"slotSize":[[728,90],[320,50],[300,100],[300,50]]},{"viewport":[320,50],"slotSize":[[320,100],[320,50],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[992,0],"sizes":[[970,250],[728,90],[320,100],[300,100]]},{"minViewPort":[768,0],"sizes":[[728,90],[320,50],[300,100],[300,50]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,100],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"foot"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"foot","breakpoints":[],"loadsAutomatically":true}');
#                 </script></div></div></div><div class="_footer_content_1n2qg_7 _container_18ask_1"><div class="_grid_1p4mq_1"><a class="_container_vhroe_1 _brand_link_1n2qg_72" data-testid="brand-link_testID" href="https://www.timeout.com">Time Out</a></div><div class="_container_1oyto_1" data-testid="footer-links_testID"><div class="_content_1oyto_5"><div class="_column_1oyto_24 _columnFollowUs_1oyto_30"></div><div class="_column_1oyto_24"><p class="_title_1oyto_11"><a href="https://www.timeout.com/about" target="_blank"><span>About us</span></a></p><ul class="_list_1oyto_36"><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/latest-news" target="_blank">Press office</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/investors" target="_blank">Investor relations</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/awards" target="_blank">Our awards</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/work-for-time-out" target="_blank">Work for Time Out</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/editorial-guidelines" target="_blank">Editorial guidelines</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/privacy-notice" target="_blank">Privacy notice</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/privacy-notice#CCPA" target="_blank">Do not sell my information</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/cookie-policy" target="_blank">Cookie policy</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/accessibility-statement" target="_blank">Accessibility statement</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/terms-of-use" target="_blank">Terms of use</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://assets.timeout.com/application/pdf/292e5c797496115d6f0ecadcefd3fb18/modern_slavery_statement2019.pdf" target="_blank">Modern slavery statement</a></li><li class="_listItem_1oyto_42 navigation_manage_cookies"><a class="_listLink_1oyto_48" href="" target="">Manage cookies</a></li></ul></div><div class="_column_1oyto_24"><p class="_title_1oyto_11"><a href="https://www.timeout.com/about/contact-us" target="_blank"><span>Contact us</span></a></p><ul class="_list_1oyto_36"><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeout.com/about/commercial-opportunities" target="_blank">Advertising</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="https://www.timeoutmarket.com/" target="_blank">Time Out Market</a></li></ul></div><div class="_column_1oyto_24"><p class="_title_1oyto_11"><span>Time Out Worldwide</span></p><ul class="_list_1oyto_36"><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/about/time-out-destinations" target="_self">All Time Out Locations</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/africa" target="_self">Africa</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/asia" target="_self">Asia</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/europe" target="_self">Europe</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/north-america" target="_self">North America</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/south-america" target="_self">South America</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/south-pacific" target="_self">South Pacific</a></li><li class="_listItem_1oyto_42"><a class="_listLink_1oyto_48" href="/metaverse" target="_self">Metaverse</ ...
# (function(h,o,t,j,a,r){
#     h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#     h._hjSettings={hjid:380860,hjsv:6};
#     a=o.getElementsByTagName('head')[0];
#     r=o.createElement('script');r.async=1;
#     r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#     a.appendChild(r);
# })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');</script><div data-component="gtm-data-layer"></div><script>window._taboola = window._taboola || [];
#     _taboola.push({flush: true});</script></body></html>

# %% [markdown]
# #### Building the dataframe

# %%
#your code here
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <link href="/static/images/favicon.ico" rel="icon" sizes="16x16" type="image/x-icon"/>
#   <link href="/static/images/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/static/images/favicon-48.png" rel="icon" sizes="48x48" type="image/png"/>
#   <link href="/static/images/favicon-180.png" rel="apple-touch-icon" type="image/png"/>
#   <title>
#    100 Best Movies of All Time That You Should Watch Immediately
#   </title>
#   <meta content="We have ranked the best movies of all time that our film editors say you need to watch. Which movie is your favourite?" name="description"/>
#   <link href="https://www.timeout.com/film/best-movies-of-all-time" rel="canonical"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <script>
#    window.digitalData = {"pageInstanceID":"web-uk-worldwide.127741-prod","version":"1.0","timestamp":1707736828238,"page":{"pageInfo":{"placeId":1,"sysEnv":"prod","city":"Worldwide","hourOfDay":"11","dayOfWeek":"Monday","version":5,"language":"en","country":"UK","locale":"en-GB","siteId":"uk-worldwide","isOO":"true","reportSuites":"timeoutworldwide","pageID":"127741","author":"Phil de Semlyen, Joshua Rothkopf, Matthew Singer","pageName":"the 100 best movies of all time : feature page","contentTitle":"The 100 best movies of all time","contentID":"content-page-127741","contentType":"feature","siteSection":"the 100 best movies of all time : feature page","destinationURL":"https://www.timeout.com/film/best-movies-of-all-time","publishDate":"2024-02-09T04:09:24Z","createdDate":"2019-05-20T21:08:44+01:00","displayPublishDate":true,"pagination":"","canaryID":"False"},"category":{"primaryCategory":"film (category)","primaryCategoryRepresentation":"Film","subCategory1":"","pageTags":["Film","Categories: Film","Format: Big film list","global kickers: Time In"],"pageType":"feature","nlp":["Night of the Living Dead","Stephen Garrett","Anna Smith","Ian Freer","Joshua Rothkopf","George A. Romero","Dave Calhoun","Phil de Semlyen","Tomris Laffly","Bilge Ebiri","Matthew Singer","Jordan Peele","Peele","Abbey Bender"]},"attributes":{"commercial":{"enabled":false,"type":"","authorOverride":""},"social":{"title":"100 Best Movies of All Time That You Should Watch Immediately","subTitle":"Which movie is your favourite?"},"description":"In case you couldn&rsquo;t tell, we love movies &ndash; and if you&rsquo;re reading this, presumably you do, too. Who doesn&rsquo;t, really? That&rsquo;s not a controversial statement. The controversy happens when you start talking about the greatest movies of all-time. Because while everyone loves getting lost in a film for two-plus hours, not everyone loves the same films. Tastes in cinema vary wildly, of course: one person&rsquo;s Citizen Kane is another&rsquo;s Deuce Bigalow: Male Gigolo, or vice versa. (Hey, it&rsquo;s possible.)&nbsp;&nbsp;\r\nThat can make ranking the best movies ever made a fraught process. But the point of the list you&rsquo;re about to peruse isn&rsquo;t to solidify any sort of canon. It&rsquo;s better to think of it as a roadmap. If you&rsquo;re just beginning to fill in the gaps of your movie knowledge, this is the perfect way to identify the holes. And if you&rsquo;re enough of a cinephile to have seen every movie on here already, it might cause you to rethink your own personal rankings. It&rsquo;s a list that covers a lot of ground: over 100 years, multiple countries, and just about every genre you can imagine, from monolithic blockbusters to treasured cult classics, ridiculous comedies to freaky horror, sweaty-palmed thrillers to eye-popping action flicks. So get exploring &ndash; you may not like everything you see, but we&rsquo;re confident you&rsquo;ll find something that surprises you.\r\nWritten by Abbey Bender, Dave Calhoun, Phil de Semlyen, Bilge Ebiri, Ian Freer, Stephen Garrett, Tomris Laffly, Joshua Rothkopf, Anna Smith and Matthew Singer\r\nRecommended:\r\n🏆 The 100 greatest horror films&nbsp;ever made🔥 The best films of 2023 (so far)📺 The&nbsp;100 greatest ever TV shows you need to binge🤣 The best funny films of all-time","shortDescription":"Silent classics, noirs, space operas and everything in between: Somehow we managed to rank the best movies of all time","subTitle":"Silent classics, noirs, space operas and everything in between: Somehow we managed to rank the best movies of all time","image":"https://media.timeout.com/images/102793667/image.jpg","imageCredit":"\"Goodfellas\"","comscoreId":"7021684"}}};
#   </script>
#   <meta data-component="omniture" data-config='{"primaryDisplayName":"","omnitureSiteName":"Worldwide EN"}' data-track-manually="false"/>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   </script>
#   <script data-testid="gtm_testID">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NHG693B');
#   </script>
#   <link href="/static/css/main-5e2aeb03a91e51cdda59f8ede08ff4d7.css" rel="stylesheet"/>
#   <link href="/static/css/listfeature-c88025cb655edb219a222409ece376a9.css" rel="stylesheet"/>
#   <link as="style" href="/static/css/bedrock-2978f17ce5dc2012de0ebc89a4b9fde7.css" id="bedrock" rel="preload"/>
#   <link crossorigin="" href="https://cdn.permutive.com" rel="preconnect"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/roboto-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/roboto-bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/franklin-gothic-lt-pro-dm-cm.woff2" rel="preload" type="font/woff2"/>
#   <link as="image" href="https://media.timeout.com/images/102793667/400/225/image.jpg" rel="preload"/>
#   <link as="image" href="https://media.timeout.com/images/102793667/750/422/image.jpg" rel="preload"/>
#   <link as="image" href="https://media.timeout.com/images/102793667/1024/576/image.jpg" rel="preload"/>
#   <link as="image" href="https://media.timeout.com/images/102793667/1372/772/image.jpg" rel="preload"/>
#   <link as="image" href="https://media.timeout.com/images/102793667/1536/864/image.jpg" rel="preload"/>
#   <link as="image" href="https://media.timeout.com/images/102793667/1920/1080/image.jpg" rel="preload"/>
#   <script>
#    window.adGlobals = window.adGlobals || {};
#
#           window.adGlobals.gptParams = window.adGlobals.gptParams || {
#             host: 'timeout.uk.worldwide.en',
#             network_code: '5185',
#             zone: 'film',
#             category: 'film',
#             page: 'feature',
#             itemid: 'page-127741',
#             audience: 'default',
#             source: 'Direct',
#             editorial_host: 'Worldwide',
#             canary: 'false',
#             hero_full_width: 'false',
#             prototype: 'false'
#             , kicker: ['time-in']
#
#             , nlp: ['Night of the Living Dead', 'Stephen Garrett', 'Anna Smith', 'Ian Freer', 'Joshua Rothkopf', 'George A. Romero', 'Dave Calhoun', 'Phil de Semlyen', 'Tomris Laffly', 'Bilge Ebiri', 'Matthew Singer', 'Jordan Peele', 'Peele', 'Abbey Bender']
#           }
#   </script>
#   <script src="/static/js/store-2fab580a224dda9dbaeb.js">
#   </script>
#   <script async="" src="/static/js/cmp-95e95cfb1e13e3347f7e.js">
#   </script>
#   <script async="" src="/static/js/permutive-871b990eb66e4f6c1474.js">
#   </script>
#   <script async="" src="https://cdn.permutive.com/67cbf6c5-d926-407b-a684-a0606570ff08-web.js">
#   </script>
#   <script async="" src="https://micro.rubiconproject.com/prebid/dynamic/11092.js?canary=false&amp;host=timeout.uk.worldwide.en">
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script defer="" src="/static/js/ads-4299e8347ebd48dcc71b.js">
#   </script>
#   <script defer="" src="/static/js/libs-e32bb1f00a37335f840f.js">
#   </script>
#   <script defer="" src="/static/js/main-3c388e2b65c5d23c551d.js">
#   </script>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="100 Best Movies of All Time That You Should Watch Immediately" name="twitter:title"/>
#   <meta content="Which movie is your favourite?" name="twitter:description"/>
#   <meta content="https://media.timeout.com/images/102793667/image.jpg" property="twitter:image"/>
#   <meta content="100 Best Movies of All Time That You Should Watch Immediately" property="og:title"/>
#   <meta content="Which movie is your favourite?" property="og:description"/>
#   <meta content="https://www.timeout.com/film/best-movies-of-all-time" property="og:url"/>
#   <meta content="https://media.timeout.com/images/102793667/image.jpg" property="og:image"/>
#   <meta content="en-GB" property="og:locale"/>
#   <meta content="110523762296825" property="fb:app_id"/>
#   <meta content="Time Out Worldwide" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="108567654280858,1670703719868417,174242829266612,120767178004956,155014857903554,110806252326039,409399439112038,1446189005633181,1640139182938675,726032854137181,127115470664822,199312830102994,277086222458072,225473697480565,176178312421715,260316788252,24247856516,114687728553778,39439020663,425095207624727,167113240025188,87396842402,130436867619222,79807336765,323652267735749,49342614805,364918466158,1658004801141837,920467047965637,297605497404,756469617704922,646556245421580,143754132316142,34127084244,308385419176623,55290780338,127485225400,609582352454281,384475866176,1423947147859126,631789766893061,321104281941901" property="fb:pages"/>
#   <meta content="uk-worldwide" name="site"/>
#   <meta content="en-GB" name="locale"/>
#   <meta content="https://discover.timeout.com/v1" name="discover"/>
#   <meta content="https://auth.timeout.com/api/subscribe" name="auth"/>
#   <script>
#    window._taboola = window._taboola || [];
#     _taboola.push({article:'auto'});
#     !function (e, f, u, i) {
#       if (!document.getElementById(i)){
#         e.async = 1;
#         e.src = u;
#         e.id = i;
#         f.parentNode.insertBefore(e, f);
#       }
#     }(document.createElement('script'),
#     document.getElementsByTagName('script')[0],
#     '//cdn.taboola.com/libtrc/timeoutmediagroup-timeoutcomen/loader.js',
#     'tb_loader_script');
#     if(window.performance && typeof window.performance.mark == 'function')
#       {window.performance.mark('tbl_ic');}
#   </script>
#   <meta content="post" name="parsely-type"/>
#   <meta content="100 Best Movies of All Time That You Should Watch Immediately" name="parsely-title"/>
#   <meta content="https://www.timeout.com/film/best-movies-of-all-time" name="parsely-link"/>
#   <meta content="https://media.timeout.com/images/102793667/image.jpg" name="parsely-image-url"/>
#   <meta content="2024-02-08T00:00:00Z" name="parsely-pub-date"/>
#   <meta content="Worldwide" name="parsely-section"/>
#   <meta content="Phil de Semlyen" name="parsely-author"/>
#   <meta content="Joshua Rothkopf" name="parsely-author"/>
#   <meta content="Matthew Singer" name="parsely-author"/>
#   <meta content="Film, Categories: Film, Format: Big film list, global kickers: Time In" name="parsely-tags"/>
#  </head>
#  <body data-page-type="feature">
#   <div class="_ad_1elek_1 _ad-skin_1elek_40" data-testid="ad_testID" id="ad-skin-1-9955">
#    <script>
#     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/skin/feature","adContainerId":"ad-skin-1-9955","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[1,1]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"skin"}],"adSenseTags":[],"adSlotGroup":"skin","breakpoints":["xl"],"loadsAutomatically":true}');
#    </script>
#   </div>
#   <div class="_ad_1elek_1 _ad-oop_1elek_15" data-testid="ad_testID" id="ad-oop-1-1042">
#    <script>
#     window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/oop/feature","adContainerId":"ad-oop-1-1042","isOutOfPage":true,"isRegistered":false,"adSizes":[],"adTags":[{"key":"type","value":"oop"}],"adSenseTags":[],"adSlotGroup":"oop","breakpoints":[],"loadsAutomatically":true}');
#    </script>
#   </div>
#   <script>
#    window._TO = window._TO || {};
# window._TO.frontendTranslations = window._TO.frontendTranslations || {
# 'JWPLAYER.geoblocking_error': 'This video is not available in your location.'
# }
#   </script>
#   <section class="_skipLinks_8n5ih_1" data-testid="skip-links_testID">
#    <a aria-hidden="true" href="#main-container">
#     Go to the content
#    </a>
#    <a aria-hidden="true" href="#site-footer">
#     Go to the footer
#    </a>
#   </section>
#   <div class="_overlay_kzzn5_1" data-component="popup-newsletter" hidden="" id="popup-newsletter">
#    <div class="_popupNewsletterContainer_kzzn5_36" id="popup-newsletter-container">
#     <button class="_closeButton_kzzn5_73" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-close-button">
#      <svg viewbox="0 0 15 15" xmlns="http://www.w3.org/2000/svg">
#       <path d="M9.54594 7.42462L14.8492 2.12132L12.7279 0L7.42462 5.3033L2.12132 0L9.53674e-07 2.12132L5.3033 7.42462L9.53674e-07 12.7279L2.12132 14.8492L7.42462 9.54594L12.7279 14.8492L14.8492 12.7279L9.54594 7.42462Z">
#       </path>
#      </svg>
#      <span class="_text-hide_v9moj_1">
#       No thanks
#      </span>
#     </button>
#     <div class="_popupMainContent_kzzn5_66">
#      <div class="_successMessageContainer_kzzn5_22">
#       <p class="_successMessageTitle_kzzn5_115">
#        Awesome, you're subscribed!
#       </p>
#       <p class="_successMessageText_kzzn5_125">
#        Thanks for subscribing! Look out for your first newsletter in your inbox soon!
#       </p>
#      </div>
#      <form class="_form_kzzn5_108">
#       <p class="_title_kzzn5_114" id="popup-newsletter-title">
#        The best things in life are free.
#       </p>
#       <p class="_message_kzzn5_124" id="popup-newsletter-message">
#        Sign up for our email to enjoy your city without spending a thing (as well as some options when you’re feeling flush).
#       </p>
#       <label class="_text-hide_v9moj_1" for="popup-newsletter-email">
#        Enter email address
#       </label>
#       <div class="_textWrap_kzzn5_139">
#        <p class="_errorMessage_kzzn5_157">
#         Déjà vu! We already have this email. Try another?
#        </p>
#        <input class="_textInput_kzzn5_144 _email_kzzn5_177" data-private="lipsum" id="popup-newsletter-email" name="email" placeholder="Enter email address" required="" type="email"/>
#       </div>
#       <input class="_submitButton_kzzn5_182" type="submit" value="Subscribe now"/>
#      </form>
#      <a class="_dismissButton_kzzn5_217" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-dismiss-button">
#       No thanks
#      </a>
#      <div class="_disclaimer_kzzn5_234" id="popup-newsletter-disclaimer">
#       <p>
#        By entering your email address you agree to our
#        <a href="https://www.timeout.com/terms-of-use" target="_blank">
#         Terms of Use
#        </a>
#        and
#        <a href="https://www.timeout.com/privacy-notice" target="_blank">
#         Privacy Policy
#        </a>
#        and consent to receive emails from Time Out about news, events, offers and partner promotions.
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="_overlay_kzzn5_1" data-component="popup-gate-newsletter" hidden="" id="popup-gate-newsletter">
#    <div class="_popupNewsletterContainer_kzzn5_36" id="popup-newsletter-container">
#     <button class="_closeButton_kzzn5_73" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-close-button">
#      <svg viewbox="0 0 15 15" xmlns="http://www.w3.org/2000/svg">
#       <path d="M9.54594 7.42462L14.8492 2.12132L12.7279 0L7.42462 5.3033L2.12132 0L9.53674e-07 2.12132L5.3033 7.42462L9.53674e-07 12.7279L2.12132 14.8492L7.42462 9.54594L12.7279 14.8492L14.8492 12.7279L9.54594 7.42462Z">
#       </path>
#      </svg>
#      <span class="_text-hide_v9moj_1">
#       No thanks
#      </span>
#     </button>
#     <div class="_popupMainContent_kzzn5_66">
#      <div class="_successMessageContainer_kzzn5_22">
#       <p class="_successMessageTitle_kzzn5_115">
#        Awesome, you're subscribed!
#       </p>
#       <p class="_successMessageText_kzzn5_125">
#        Thanks for subscribing! Look out for your first newsletter in your inbox soon!
#       </p>
#      </div>
#      <form class="_form_kzzn5_108">
#       <p class="_title_kzzn5_114" id="popup-newsletter-title">
#        Love the mag?
#       </p>
#       <p class="_message_kzzn5_124" id="popup-newsletter-message">
#        Our newsletter hand-delivers the best bits to your inbox. Sign up to unlock our digital magazines and also receive the latest news, events, offers and partner promotions.
#       </p>
#       <label class="_text-hide_v9moj_1" for="popup-gate-newsletter-email">
#        Enter email address
#       </label>
#       <div class="_textWrap_kzzn5_139">
#        <p class="_errorMessage_kzzn5_157">
#         Déjà vu! We already have this email. Try another?
#        </p>
#        <input class="_textInput_kzzn5_144 _email_kzzn5_177" data-private="lipsum" id="popup-gate-newsletter-email" name="email" placeholder="Enter email address" required="" type="email"/>
#       </div>
#       <input class="_submitButton_kzzn5_182" type="submit" value="Subscribe now"/>
#      </form>
#      <a class="_dismissButton_kzzn5_217" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","event":"custom-click","category":"TO Engagement"}}' id="popup-newsletter-dismiss-button">
#       No thanks
#      </a>
#      <div class="_disclaimer_kzzn5_234" id="popup-newsletter-disclaimer">
#       <p>
#        By entering your email address you agree to our
#        <a href="https://www.timeout.com/terms-of-use" target="_blank">
#         Terms of Use
#        </a>
#        and
#        <a href="https://www.timeout.com/privacy-notice" target="_blank">
#         Privacy Policy
#        </a>
#        and consent to receive emails from Time Out about news, events, offers and partner promotions.
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="_adsContainer_1q8qx_18 _full-width-ui_1elek_111" data-component="sticky-header">
#    <div class="_ad_1elek_1 _ad-head_1elek_21" data-testid="ad_testID" id="ad-head-1-41">
#     <script>
#      window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/head/feature","adContainerId":"ad-head-1-41","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[970,250],[728,90]]},{"viewport":[768,50],"slotSize":[[728,90],[320,100],[300,100],[320,50],[300,50]]},{"viewport":[320,50],"slotSize":[[320,100],[320,50],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[800,0],"sizes":[[970,250],[728,90]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"head"}],"adSenseTags":[],"adSlotGroup":"head","breakpoints":[],"loadsAutomatically":true}');
#     </script>
#    </div>
#   </div>
#   <header class="_header_7dcbk_1 _full-width-ui_1elek_111">
#    <div class="_container_18ask_1 _headerOuterContainer_7dcbk_152" data-component="masthead">
#     <div class="_grid_1p4mq_1">
#      <section class="_header_1p4mq_10">
#       <div class="_headerContainer_7dcbk_12">
#        <div class="_content_7dcbk_34">
#         <div class="_left_7dcbk_80">
#          <div class="_sm_7dcbk_130 _navigationDrawerCtaContainer_7dcbk_60">
#           <div class="_container_ty2xw_4" data-testid="navigation-drawer_testID">
#            <input class="_checkbox_ty2xw_1" data-navigation-toggle="true" data-testid="navigation-cta_testID" id="checkbox-navigation-toggle" type="checkbox"/>
#            <div class="_overlay_ty2xw_1">
#            </div>
#            <label class="_label_ty2xw_1" for="checkbox-navigation-toggle">
#             <a class="_cta_ty2xw_1">
#              <svg viewbox="0 0 24.1 18" xmlns="http://www.w3.org/2000/svg">
#               <path d="M22.832 15.545a1.227 1.227 0 010 2.455H1.227a1.227 1.227 0 110-2.455zm0-7.772a1.227 1.227 0 010 2.454H1.227a1.227 1.227 0 110-2.454zm0-7.773a1.227 1.227 0 010 2.455H1.227a1.227 1.227 0 110-2.455z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </a>
#             <a class="_cta_ty2xw_1 _close_ty2xw_1">
#              <svg viewbox="0 0 22 18" xmlns="http://www.w3.org/2000/svg">
#               <path d="M4.406 17.43c.188.21.422.312.703.312.246 0 .48-.101.7-.312l6.25-6.02 6.25 6.02c.218.21.453.312.699.312a.885.885 0 00.699-.312c.25-.211.375-.426.375-.653 0-.222-.125-.457-.375-.695l-6.25-6.02 6.25-6.019c.25-.238.375-.473.375-.695 0-.227-.125-.442-.375-.653-.215-.238-.441-.36-.676-.36-.23 0-.472.122-.722.36l-6.25 6.02-6.25-6.02c-.25-.238-.493-.36-.723-.36-.234 0-.461.122-.68.36-.246.211-.37.426-.37.653 0 .222.124.457.37.695l6.254 6.02-6.254 6.019c-.246.238-.37.473-.37.695 0 .227.124.442.37.653zm0 0">
#               </path>
#              </svg>
#              <span class="_text-hide_v9moj_1">
#               Close
#              </span>
#             </a>
#            </label>
#            <div class="_nav_ty2xw_1" data-testid="navigation-menu_testID">
#             <div class="_header_ty2xw_1">
#              <span>
#               Worldwide
#              </span>
#             </div>
#             <ul class="_ul_ty2xw_1" data-testid="navigation-menu_sections-with-seperator_testID">
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/news" target="_self">
#                News
#               </a>
#              </li>
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/things-to-do" target="_self">
#                Things to Do
#               </a>
#              </li>
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/food-and-drink" target="_self">
#                Food &amp; Drink
#               </a>
#              </li>
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/arts-and-culture" target="_self">
#                Arts &amp; Culture
#               </a>
#              </li>
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/travel" target="_self">
#                Travel
#               </a>
#              </li>
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/movies" target="_self">
#                Movies
#               </a>
#              </li>
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/music" target="_self">
#                Music
#               </a>
#              </li>
#              <li class="_item_ty2xw_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","event":"custom-click","category":"GP Engagement"}}' href="/time-out-market" target="_self">
#                Time Out Market
#               </a>
#              </li>
#             </ul>
#             <div class="_popularCities_ty2xw_1">
#              <input data-animated-chevron-input="true" data-navigation-popular-cities-toggle="true" id="checkbox-navigation-popular-cities-toggle" type="checkbox"/>
#              <label class="_popularCitiesLabel_ty2xw_1" for="checkbox-navigation-popular-cities-toggle">
#               Popular cities
#               <span class="_animatedChevron_c3wq1_1">
#               </span>
#              </label>
#              <ul>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/london">
#                 London
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/newyork">
#                 New York
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/paris/en">
#                 Paris
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/chicago">
#                 Chicago
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/los-angeles">
#                 Los Angeles
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/lisbon">
#                 Lisbon
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/hong-kong">
#                 Hong Kong
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/sydney">
#                 Sydney
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/melbourne">
#                 Melbourne
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/porto">
#                 Porto
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/singapore">
#                 Singapore
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/barcelona">
#                 Barcelona
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/madrid">
#                 Madrid
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/montreal">
#                 Montreal
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/boston">
#                 Boston
#                </a>
#               </li>
#               <li class="_itemPopularCities_ty2xw_1">
#                <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/miami">
#                 Miami
#                </a>
#               </li>
#              </ul>
#             </div>
#             <ul class="_languages_ty2xw_1">
#              <li class="_item_languages_ty2xw_1">
#               <span>
#                EN
#               </span>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/pt">
#                PT
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/es">
#                ES
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/fr">
#                FR
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/hk">
#                ZH
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/ca">
#                CA
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/ko">
#                KO
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/th">
#                TH
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/ru">
#                RU
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/ja">
#                JA
#               </a>
#              </li>
#              <li class="_item_languages_ty2xw_1">
#               <a href="/tr">
#                TR
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="_md-f_7dcbk_119 _selectorsContainer_7dcbk_114">
#           <div class="_container_u8fp1_4" data-testid="city-selector_testID">
#            <input class="_checkbox_u8fp1_1" data-animated-chevron-input="true" data-city-selector="true" data-testid="city-selector-cta_testID" id="checkbox-city-selector" name="masthead-dropdowns" type="radio"/>
#            <label for="checkbox-city-selector">
#             <a class="_cta_u8fp1_1">
#              <span>
#               Worldwide
#              </span>
#              <span class="_animatedChevron_c3wq1_1 _small_c3wq1_19">
#              </span>
#             </a>
#            </label>
#            <div class="_listContainer_u8fp1_1 preload" data-testid="city-selector-list_testID">
#             <span class="_title_u8fp1_1">
#              Popular cities
#             </span>
#             <ul class="_ul_u8fp1_1">
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/london">
#                London
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/newyork">
#                New York
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/paris/en">
#                Paris
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/chicago">
#                Chicago
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/los-angeles">
#                Los Angeles
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/lisbon">
#                Lisbon
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/hong-kong">
#                Hong Kong
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/sydney">
#                Sydney
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/melbourne">
#                Melbourne
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/porto">
#                Porto
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/singapore">
#                Singapore
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/barcelona">
#                Barcelona
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/madrid">
#                Madrid
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/montreal">
#                Montreal
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/boston">
#                Boston
#               </a>
#              </li>
#              <li class="_li_u8fp1_1">
#               <a data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="/miami">
#                Miami
#               </a>
#              </li>
#             </ul>
#             <a class="_a_u8fp1_1" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","category":"GP Engagement","label":"navigation bar","event":"custom-click"}}' href="https://www.timeout.com">
#              Browse all cities
#              <svg viewbox="0 0 15.5 11.5" xmlns="http://www.w3.org/2000/svg">
#               <path d="M11.586 6.748H0v-2h11.586L8.252 1.414 9.667 0l5.747 5.748-5.747 5.747-1.415-1.414z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </a>
#            </div>
#           </div>
#           <div class="_container_p7aiv_4 lang-picker" data-testid="language-selector_testID">
#            <input class="_checkbox_p7aiv_1" data-animated-chevron-input="true" data-language-selector="true" data-testid="language-selector-cta_testID" id="checkbox-language-selector" name="masthead-dropdowns" type="radio" value="language-selector"/>
#            <label for="checkbox-language-selector">
#             <a class="_cta_p7aiv_1">
#              EN
#              <span class="_animatedChevron_c3wq1_1 _small_c3wq1_19">
#              </span>
#             </a>
#            </label>
#            <ul class="_ul_p7aiv_1 preload" data-testid="language-selector-list_testID">
#             <li class="_selected_p7aiv_1">
#              <svg viewbox="0 0 20.8 18.5" xmlns="http://www.w3.org/2000/svg">
#               <path d="M19.281 5.281L9 15.563 4.719 11.28 3.28 12.72l5 5 .719.687.719-.687 11-11z">
#               </path>
#              </svg>
#              <span>
#               English
#              </span>
#             </li>
#             <li class="">
#              <a href="/pt">
#               Português
#              </a>
#             </li>
#             <li class="">
#              <a href="/es">
#               Español
#              </a>
#             </li>
#             <li class="">
#              <a href="/fr">
#               Français
#              </a>
#             </li>
#             <li class="">
#              <a href="/hk">
#               中文
#              </a>
#             </li>
#             <li class="">
#              <a href="/ca">
#               Català
#              </a>
#             </li>
#             <li class="">
#              <a href="/ko">
#               한국어
#              </a>
#             </li>
#             <li class="">
#              <a href="/th">
#               ไทย
#              </a>
#             </li>
#             <li class="">
#              <a href="/ru">
#               Русский
#              </a>
#             </li>
#             <li class="">
#              <a href="/ja">
#               日本語
#              </a>
#             </li>
#             <li class="">
#              <a href="/tr">
#               Türkçe
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="_middle_7dcbk_73">
#          <a class="_logo_7dcbk_38" href="https://www.timeout.com">
#           Timeout
#          </a>
#         </div>
#         <div class="_right_7dcbk_65">
#          <div class="_mailButton_7dcbk_103">
#           <div class="_container_edb82_1" data-component="nav-newsletter">
#            <input class="_checkboxNav_1n32g_15" data-nav-newsletter="true" id="checkbox-nav-newsletter" name="newsletter-dropdown" type="checkbox"/>
#            <label class="_label_1n32g_19" for="checkbox-nav-newsletter">
#             <a class="_navBarCta_1n32g_1" data-data-layer='{"triggerOn":0,"payload":{"action":"click - subscribe","label":"newsletter","event":"custom-click","category":"TO Engagement"}}'>
#              <svg viewbox="0 0 31 23" xmlns="http://www.w3.org/2000/svg">
#               <path d="M0 18.012c0 1.37.489 2.543 1.467 3.52C2.445 22.512 3.62 23 4.988 23h20.07c1.37 0 2.544-.489 3.522-1.467.978-.978 1.467-2.152 1.467-3.521V4.988c0-1.37-.49-2.543-1.467-3.52C27.602.488 26.428 0 25.059 0H4.989c-1.37 0-2.544.489-3.522 1.467C.49 2.445 0 3.62 0 4.988v13.024zm2.523 0V4.988c0-.195.079-.528.235-.997l11.503 9.39c.156.156.41.234.762.234.196 0 .45-.078.763-.235l11.62-9.272c.078.235.117.528.117.88v13.024c0 .665-.244 1.252-.733 1.76-.49.509-1.066.763-1.731.763H4.989c-.666 0-1.243-.254-1.732-.763-.489-.508-.734-1.095-.734-1.76zm2.23-15.547h20.775l-10.505 8.392-10.27-8.392z">
#               </path>
#              </svg>
#              <span>
#               Subscribe
#              </span>
#             </a>
#            </label>
#            <div class="_container_12c49_36">
#             <div class="_containerWrap_12c49_60">
#              <button class="_close_12c49_76" data-data-layer='{"triggerOn":0,"payload":{"action":"click - dismiss","label":"newsletter","category":"GP Engagement","event":"custom-click"}}'>
#               <svg viewbox="0 0 22 18" xmlns="http://www.w3.org/2000/svg">
#                <path d="M4.406 17.43c.188.21.422.312.703.312.246 0 .48-.101.7-.312l6.25-6.02 6.25 6.02c.218.21.453.312.699.312a.885.885 0 00.699-.312c.25-.211.375-.426.375-.653 0-.222-.125-.457-.375-.695l-6.25-6.02 6.25-6.019c.25-.238.375-.473.375-.695 0-.227-.125-.442-.375-.653-.215-.238-.441-.36-.676-.36-.23 0-.472.122-.722.36l-6.25 6.02-6.25-6.02c-.25-.238-.493-.36-.723-.36-.234 0-.461.122-.68.36-.246.211-.37.426-.37.653 0 .222.124.457.37.695l6.254 6.02-6.254 6.019c-.246.238-.37.473-.37.695 0 .227.124.442.37.653zm0 0">
#                </path>
#               </svg>
#               <span class="_text-hide_v9moj_1">
#                Close
#               </span>
#              </button>
#              <div class="_content_12c49_1">
#               <div>
#                <p class="_title_12c49_5">
#                 Get us in your inbox
#                </p>
#                <form class="_form_12c49_109">
#                 <label class="_label_12c49_9" for="nav_news_input">
#                  Sign up to our newsletter for the latest and greatest from your city and beyond
#                 </label>
#                 <div class="_formRow_12c49_115">
#                  <input class="_inputEmail_12c49_128" data-private="lipsum" id="nav_news_input" placeholder="Enter email address" required="" type="email"/>
#                  <p class="_error_12c49_13" hidden="">
#                   Déjà vu! We already have this email. Try another?
#                  </p>
#                 </div>
#                 <input class="_submit_12c49_144" type="submit" value="Subscribe now"/>
#                </form>
#                <div class="_consent_12c49_18">
#                 <p>
#                  By entering your email address you agree to our
#                  <a href="https://www.timeout.com/terms-of-use" target="_blank">
#                   Terms of Use
#                  </a>
#                  and
#                  <a href="https://www.timeout.com/privacy-notice" target="_blank">
#                   Privacy Policy
#                  </a>
#                  and consent to receive emails from Time Out about news, events, offers and partner promotions.
#                 </p>
#                </div>
#               </div>
#               <div data-nav-newsletter-success-container="true" hidden="">
#                <p class="_successTitle_12c49_28">
#                 🙌 Awesome, you're subscribed!
#                </p>
#                <p class="_successDescription_12c49_32">
#                 Thanks for subscribing! Look out for your first newsletter in your inbox soon!
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </header>
#   <div class="navigation-desktop _container_1nhv4_1 _full-width-ui_1elek_111" data-component="navigation-bar">
#    <nav class="_br_row_18ask_7">
#     <ul class="_ulNav_1nhv4_9 _layout_center_1nhv4_17">
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/news" target="_self" title="News">
#        News
#       </a>
#      </li>
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/things-to-do" target="_self" title="Things to Do">
#        Things to Do
#       </a>
#      </li>
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/food-and-drink" target="_self" title="Food &amp; Drink">
#        Food &amp; Drink
#       </a>
#      </li>
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/arts-and-culture" target="_self" title="Arts &amp; Culture">
#        Arts &amp; Culture
#       </a>
#      </li>
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/travel" target="_self" title="Travel">
#        Travel
#       </a>
#      </li>
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/movies" target="_self" title="Movies">
#        Movies
#       </a>
#      </li>
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/music" target="_self" title="Music">
#        Music
#       </a>
#      </li>
#      <li class="_li_1nhv4_22">
#       <a class="_navItem_1nhv4_28" data-data-layer='{"triggerOn":0,"payload":{"action":"link - internal","label":"navigation bar","category":"GP Engagement"}}' href="/time-out-market" target="_self" title="Time Out Market">
#        Time Out Market
#       </a>
#      </li>
#      <li class="_hasSubNav_1nhv4_23" data-animated-chevron-container="true" hidden="" tabindex="0">
#       <span class="_subnavToggle_1nhv4_84">
#        <span class="_subnavText_1nhv4_55" title="More">
#         More
#        </span>
#        <span class="_animatedChevron_c3wq1_1">
#        </span>
#       </span>
#       <ul class="_ulSubNav_1nhv4_106 _subNavCol1_1nhv4_161">
#       </ul>
#      </li>
#     </ul>
#    </nav>
#   </div>
#   <div class="_container_18ask_1 _contentWrapper_18ask_14" id="main-container">
#    <main data-component="popup-gate-newsletter-cta">
#     <div class="_grid_1p4mq_1 _grid_1c83v_32">
#      <section class="_main_content_1p4mq_7">
#       <div class="_heroContainer_1c83v_1">
#        <div class="_container_14kkg_1" data-testid="hero_testID">
#         <figure class="_figure_gp1t3_1" data-testid="hero-image_testID" id="hero-image">
#          <picture>
#           <source data-srcset="https://media.timeout.com/images/102793667/400/225/image.webp 400w,https://media.timeout.com/images/102793667/750/422/image.webp 750w,https://media.timeout.com/images/102793667/1024/576/image.webp 1024w,https://media.timeout.com/images/102793667/1372/772/image.webp 1372w,https://media.timeout.com/images/102793667/1536/864/image.webp 1536w,https://media.timeout.com/images/102793667/1920/1080/image.webp 1920w" height="422" type="image/webp" width="750"/>
# ...
#           </script>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#      <aside class="_side_content_1p4mq_8">
#      </aside>
#     </div>
#     <div data-component="ecomm-widget-card">
#     </div>
#    </main>
#    <div data-component="inline-placement" data-inline-strategy="sponsored-listing" data-testid="sponsored-listing_testID">
#     <div class="_ad_1elek_1 _ad-native_1elek_55 _sponsoredListing_ra4zo_1" data-testid="ad_testID" id="ad-native-1-4258">
#      <script>
#       window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/native/feature","adContainerId":"ad-native-1-4258","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[320,50],"slotSize":[[1,1],"fluid",[712,360]]},{"viewport":[0,0],"slotSize":[]}],"adTags":[{"key":"type","value":"native"}],"adSenseTags":[],"adSlotGroup":"native","breakpoints":[],"loadsAutomatically":true}');
#      </script>
#     </div>
#     <div class="foo" data-component="native-newsletter" data-testid="native-newsletter_testID">
#      <template>
#       <div class="_container_nvs8j_1 newsletter_native">
#        <div class="row">
#         <div class="panel_form">
#          <form class="_section_form_nvs8j_7">
#           <div class="_loading_overlay_nvs8j_28 loading_overlay">
#           </div>
#           <div class="_zone_input_nvs8j_15">
#            <label class="_text-hide_v9moj_1" for="native-newsletter-email">
#             Enter email address
#            </label>
#            <input class="_email_nvs8j_59" data-private="lipsum" id="native-newsletter-email" placeholder="Enter email address" required="" type="email"/>
#            <img alt="Loading animation" class="_loading_icon_nvs8j_38 loading_icon" src="data:image/gif;base64,..."/>
#            <div class="_error_nvs8j_45 error">
#             Déjà vu! We already have this email. Try another?
#            </div>
#           </div>
#           <div class="_zone_submit_nvs8j_21">
#            <input class="_submit_nvs8j_68" type="submit" value="Subscribe now"/>
#           </div>
#          </form>
#          <div class="section_consent">
#           <p class="_consent_nvs8j_92">
#            By entering your email address you agree to our
#            <a href="https://www.timeout.com/terms-of-use" target="_blank">
#             Terms of Use
#            </a>
#            and
#            <a href="https://www.timeout.com/privacy-notice" target="_blank">
#             Privacy Policy
#            </a>
#            and consent to receive emails from Time Out about news, events, offers and partner promotions.
#           </p>
#          </div>
#         </div>
#         <div class="_panel_success_nvs8j_102 panel_success">
#          <p class="_success_title_nvs8j_106">
#           🙌 Awesome, you're subscribed!
#          </p>
#          <p class="_success_thanks_nvs8j_113">
#           Thanks for subscribing! Look out for your first newsletter in your inbox soon!
#          </p>
#         </div>
#        </div>
#       </div>
#      </template>
#     </div>
#    </div>
#   </div>
#   <div class="_container_1xvir_1 newsletter_footer _full-width-ui_1elek_111" data-component="footer-newsletter">
#    <div class="_row_1xvir_8">
#     <div class="_panel_form_1xvir_138 panel_form">
#      <div class="_section_heading_1xvir_14">
#       <p class="_form_title_1xvir_23">
#        Get us in your inbox
#       </p>
#       <label class="_label_1xvir_31">
#        Sign up to our newsletter for the latest and greatest from your city and beyond
#       </label>
#      </div>
#      <form class="_section_form_1xvir_18">
#       <div class="_loading_overlay_1xvir_35 loading_overlay">
#       </div>
#       <div class="_zone_input_1xvir_58">
#        <label class="_text-hide_v9moj_1" for="footer-newsletter-email">
#         Enter email address
#        </label>
#        <input class="_email_1xvir_70" data-private="lipsum" id="footer-newsletter-email" placeholder="Enter email address" required="" type="email"/>
#        <img alt="Loading animation" class="_loading_icon_1xvir_45 loading_icon" src="data:image/gif;base64,..."/>
#        <div class="_error_1xvir_52 error">
#         Déjà vu! We already have this email. Try another?
#        </div>
#       </div>
#       <div class="_zone_submit_1xvir_64">
#        <input class="_submit_1xvir_79" type="submit" value="Subscribe now"/>
#       </div>
#      </form>
#      <div class="_section_consent_1xvir_177">
#       <p class="_consent_1xvir_103">
#        By entering your email address you agree to our
#        <a href="https://www.timeout.com/terms-of-use" target="_blank">
#         Terms of Use
#        </a>
#        and
#        <a href="https://www.timeout.com/privacy-notice" target="_blank">
#         Privacy Policy
#        </a>
#        and consent to receive emails from Time Out about news, events, offers and partner promotions.
#       </p>
#      </div>
#     </div>
#     <div class="_panel_success_1xvir_113 panel_success">
#      <p class="_success_title_1xvir_117">
#       🙌 Awesome, you're subscribed!
#      </p>
#      <p class="_success_thanks_1xvir_124">
#       Thanks for subscribing! Look out for your first newsletter in your inbox soon!
#      </p>
#     </div>
#    </div>
#   </div>
#   <div class="_footer_1n2qg_1 _full-width-ui_1elek_111" data-testid="footer_testID" id="site-footer">
#    <div class="_footer_ad_wrap_1n2qg_43" data-component="sticky-footer">
#     <button class="_footer_ad_close_1n2qg_23">
#      <svg viewbox="0 0 22 18" xmlns="http://www.w3.org/2000/svg">
#       <path d="M4.406 17.43c.188.21.422.312.703.312.246 0 .48-.101.7-.312l6.25-6.02 6.25 6.02c.218.21.453.312.699.312a.885.885 0 00.699-.312c.25-.211.375-.426.375-.653 0-.222-.125-.457-.375-.695l-6.25-6.02 6.25-6.019c.25-.238.375-.473.375-.695 0-.227-.125-.442-.375-.653-.215-.238-.441-.36-.676-.36-.23 0-.472.122-.722.36l-6.25 6.02-6.25-6.02c-.25-.238-.493-.36-.723-.36-.234 0-.461.122-.68.36-.246.211-.37.426-.37.653 0 .222.124.457.37.695l6.254 6.02-6.254 6.019c-.246.238-.37.473-.37.695 0 .227.124.442.37.653zm0 0">
#       </path>
#      </svg>
#      <span class="_text-hide_v9moj_1">
#       Close
#      </span>
#     </button>
#     <div class="_footer_ad_1n2qg_11">
#      <div class="_ad_1elek_1 _ad-foot_1elek_22" data-testid="ad_testID" id="ad-foot-1-123">
#       <script>
#        window.rawSlots = window.rawSlots || [];
#                     window.rawSlots.push('{"adSlotId":"/5185/foot/feature","adContainerId":"ad-foot-1-123","isOutOfPage":false,"isRegistered":false,"adSizes":[{"viewport":[994,50],"slotSize":[[994,250],[970,415],[970,250],[970,90],[940,250],[900,250],[728,90],[320,100],[300,100]]},{"viewport":[768,50],"slotSize":[[728,90],[320,50],[300,100],[300,50]]},{"viewport":[320,50],"slotSize":[[320,100],[320,50],[300,100],[300,50]]},{"viewport":[0,0],"slotSize":[]}],"prebidSizes":[{"minViewPort":[992,0],"sizes":[[970,250],[728,90],[320,100],[300,100]]},{"minViewPort":[768,0],"sizes":[[728,90],[320,50],[300,100],[300,50]]},{"minViewPort":[320,0],"sizes":[[320,100],[320,50],[300,100],[300,50]]},{"minViewPort":[0,0],"sizes":[]}],"adTags":[{"key":"type","value":"foot"},{"key":"refresh","value":"30"}],"adSenseTags":[],"adSlotGroup":"foot","breakpoints":[],"loadsAutomatically":true}');
#       </script>
#      </div>
#     </div>
#    </div>
#    <div class="_footer_content_1n2qg_7 _container_18ask_1">
#     <div class="_grid_1p4mq_1">
#      <a class="_container_vhroe_1 _brand_link_1n2qg_72" data-testid="brand-link_testID" href="https://www.timeout.com">
#       Time Out
#      </a>
#     </div>
#     <div class="_container_1oyto_1" data-testid="footer-links_testID">
#      <div class="_content_1oyto_5">
#       <div class="_column_1oyto_24 _columnFollowUs_1oyto_30">
#       </div>
#       <div class="_column_1oyto_24">
#        <p class="_title_1oyto_11">
#         <a href="https://www.timeout.com/about" target="_blank">
#          <span>
#           About us
#          </span>
#         </a>
#        </p>
#        <ul class="_list_1oyto_36">
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/about/latest-news" target="_blank">
#           Press office
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/about/investors" target="_blank">
#           Investor relations
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/about/awards" target="_blank">
#           Our awards
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/about/work-for-time-out" target="_blank">
#           Work for Time Out
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/about/editorial-guidelines" target="_blank">
#           Editorial guidelines
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/privacy-notice" target="_blank">
#           Privacy notice
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/privacy-notice#CCPA" target="_blank">
#           Do not sell my information
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/cookie-policy" target="_blank">
#           Cookie policy
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/accessibility-statement" target="_blank">
#           Accessibility statement
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/terms-of-use" target="_blank">
#           Terms of use
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://assets.timeout.com/application/pdf/292e5c797496115d6f0ecadcefd3fb18/modern_slavery_statement2019.pdf" target="_blank">
#           Modern slavery statement
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42 navigation_manage_cookies">
#          <a class="_listLink_1oyto_48" href="" target="">
#           Manage cookies
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="_column_1oyto_24">
#        <p class="_title_1oyto_11">
#         <a href="https://www.timeout.com/about/contact-us" target="_blank">
#          <span>
#           Contact us
#          </span>
#         </a>
#        </p>
#        <ul class="_list_1oyto_36">
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeout.com/about/commercial-opportunities" target="_blank">
#           Advertising
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="https://www.timeoutmarket.com/" target="_blank">
#           Time Out Market
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="_column_1oyto_24">
#        <p class="_title_1oyto_11">
#         <span>
#          Time Out Worldwide
#         </span>
#        </p>
#        <ul class="_list_1oyto_36">
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/about/time-out-destinations" target="_self">
#           All Time Out Locations
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/africa" target="_self">
#           Africa
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/asia" target="_self">
#           Asia
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/europe" target="_self">
#           Europe
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/north-america" target="_self">
#           North America
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/south-america" target="_self">
#           South America
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/south-pacific" target="_self">
#           South Pacific
#          </a>
#         </li>
#         <li class="_listItem_1oyto_42">
#          <a class="_listLink_1oyto_48" href="/metaverse" target="_self">
#           Metaverse
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="_container_q3k8u_10" data-testid="legal-footer_testID">
#      <div class="_content_q3k8u_14 _grid_1p4mq_1">
#       <div class="_sitemap_q3k8u_18">
#        <a class="_flatButton_q4ci6_1" href="/sitemaps">
#         Site Map
#        </a>
#       </div>
#       <small class="_copyright_q3k8u_1">
#        © 2024 Time Out England Limited and affiliated companies owned by Time Out Group Plc. All rights reserved. Time Out is a registered trademark of Time Out Digital Limited.
#       </small>
#      </div>
#     </div>
#    </div>
#   </div>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NHG693B" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div data-component="gtm">
#   </div>
#   <div data-component="adwords">
#   </div>
#   <div data-component="inline-placement" data-inline-strategy="ad-outstream">
#   </div>
#   <div data-component="bedrock">
#   </div>
#   <div data-component="detect-ad-block" data-params='{"url":"/static/js/ajax-advert-b7c7a2d33c25f2154b7769b9dc8a4a67.js"}'>
#   </div>
#   <div data-async="true" data-id="parsely-cfg" data-lazyload="true" data-parent="head" data-src="https://cdn.parsely.com/keys/timeout.com/p.js" data-timeout="2000">
#   </div>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"Article","headline":"100 Best Movies of All Time That You Should Watch Immediately","name":"100 Best Movies of All Time That You Should Watch Immediately","image":"https://media.timeout.com/images/102793667/image.jpg","thumbnailUrl":"https://media.timeout.com/images/102793667/image.jpg","description":"Silent classics, noirs, space operas and everything in between: Somehow we managed to rank the best movies of all time","author":[{"name":"Phil de Semlyen","@type":"Person","url":"https://www.timeout.com/profile/phil-de-semlyen"},{"name":"Joshua Rothkopf","@type":"Person","url":"https://www.timeout.com/profile/joshua-rothkopf"},{"name":"Matthew Singer","@type":"Person","url":"https://www.timeout.com/profile/matthew-singer"}],"creator":"Phil de Semlyen","publisher":{"@type":"Organization","name":"Time Out","sameAs":"https://www.timeout.com","logo":{"@type":"ImageObject","url":"https://www.timeout.com/dist/img/TO_logo2x.png"}},"datePublished":"2024-02-08T00:00:00Z","url":"https://www.timeout.com/film/best-movies-of-all-time","keywords":["Film","Categories: Film","Format: Big film list","global kickers: Time In"],"articleSection":"Worldwide"}
#   </script>
#   <div data-component="ipsos-iris">
#   </div>
#   <script data-testid="hotjar_testID">
#    (function(h,o,t,j,a,r){
#     h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#     h._hjSettings={hjid:380860,hjsv:6};
#     a=o.getElementsByTagName('head')[0];
#     r=o.createElement('script');r.async=1;
#     r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#     a.appendChild(r);
# })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#   <div data-component="gtm-data-layer">
#   </div>
#   <script>
#    window._taboola = window._taboola || [];
#     _taboola.push({flush: true});
#   </script>
#  </body>
# </html>

# %%
soup.select("h3")
# Out:
# [<h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>1.</span> 2001: A Space Odyssey (1968)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>2.</span> The Godfather (1972)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>3.</span> Citizen Kane (1941)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>4.</span> Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>5.</span> Raiders of the Lost Ark (1981)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>6.</span> La Dolce Vita (1960)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>7.</span> Seven Samurai (1954)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>8.</span> In the Mood for Love (2000)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>9.</span> There Will Be Blood (2007)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>10.</span> Singin’ in the Rain (1952)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>11.</span> Goodfellas (1990)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>12.</span> North by Northwest (1959)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>13.</span> Mulholland Drive (2001)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>14.</span> Bicycle Thieves (1948)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>15.</span> The Dark Knight (2008)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>16.</span> City Lights (1931)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>17.</span> Grand Illusion (1937)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>18.</span> His Girl Friday (1940)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>19.</span> The Red Shoes (1948)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>20.</span> Vertigo (1958)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>21.</span> Beau Travail (1999)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>22.</span> The Searchers (1956)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>23.</span> Persona (1966)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>24.</span> Do the Right Thing (1989)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>25.</span> Rashomon (1950)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>26.</span> The Rules of the Game (1939)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>27.</span> Jaws (1975)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>28.</span> Double Indemnity (1944)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>29.</span> The 400 Blows (1959)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>30.</span> Star Wars (1977)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>31.</span> The Passion of Joan of Arc (1928)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>32.</span> Once Upon a Time in the West (1968)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>33.</span> Alien (1979)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>34.</span> Tokyo Story (1951)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>35.</span> Pulp Fiction (1994)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>36.</span> The Truman Show (1998)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>37.</span> Lawrence of Arabia (1962)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>38.</span> Psycho (1960)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>39.</span> Sansho the Bailiff (1954)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>40.</span> Andrei Rublev (1966)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>41.</span> The Umbrellas of Cherbourg (1964)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>42.</span> Chinatown (1974)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>43.</span> The Seventh Seal (1957)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>44.</span> Lost in Translation (2003)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>45.</span> Taxi Driver (1976)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>46.</span> Spirited Away (2001)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>47.</span> Night of the Living Dead (1968)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>48.</span> Battleship Potemkin (1925)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>49.</span> Modern Times (1936)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>50.</span> Breathless (1960)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>51.</span> Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>52.</span> M (1931)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>53.</span> Blade Runner (1982)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>54.</span> The Bitter Tears of Petra von Kant (1972)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>55.</span> Rome, Open City (1945)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>56.</span> Nosferatu (1922)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>57.</span> Airplane! (1980)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>58.</span> Under the Skin (2013)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>59.</span> Mad Max: Fury Road (2015)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>60.</span> Apocalypse Now (1979)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>61.</span> Brokeback Mountain (2005)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>62.</span> Duck Soup (1933)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>63.</span> The Blair Witch Project (1999)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>64.</span> All the President’s Men (1976)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>65.</span> The Apu trilogy (1955, 1956, 1959)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>66.</span> The General (1926)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>67.</span> Eternal Sunshine of the Spotless Mind (2004)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>68.</span> The Texas Chain Saw Massacre (1974)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>69.</span> Come and See (1985)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>70.</span> Heat (1995)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>71.</span> The Shining (1980)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>72.</span> Toy Story (1995)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>73.</span> Killer of Sheep (1977)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>74.</span> A Woman Under the Influence (1974)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>75.</span> Annie Hall (1977)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>76.</span> Some Like It Hot (1959)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>77.</span> Metropolis (1927)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>78.</span> The Maltese Falcon (1941)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>79.</span> This Is Spinal Tap (1984)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>80.</span> It Happened One Night (1934)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>81.</span> Die Hard (1988)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>82.</span> The Conformist (1970)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>83.</span> The Thing (1982)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>84.</span> Daughters of the Dust (1991)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>85.</span> Barry Lyndon (1975)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>86.</span> Raging Bull (1980)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>87.</span> Seven (1995)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>88.</span> Aguirre, the Wrath of God (1972)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>89.</span> The Battle of Algiers (1966)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>90.</span> No Country for Old Men (2007)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>91.</span> Women on the Verge of a Nervous Breakdown (1988)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>92.</span> The Discreet Charm of the Bourgeoisie (1972)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>93.</span> Paths of Glory (1957)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>94.</span> Secrets &amp; Lies (1996)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>95.</span> Sweet Smell of Success (1957)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>96.</span> The Cabinet of Dr. Caligari (1920)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>97.</span> Nashville (1975)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>98.</span> Don’t Look Now (1973)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>99.</span> Bonnie and Clyde (1967)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID"><span>100.</span> Get Out (2017)</h3>,
#  <h3 class="_h3_cuogz_1" data-testid="tile-title_testID">Check out the best movies of all time as chosen by actors</h3>]

# %%
top100m = []
for title in soup.select("h3"):
    top100m.append(title.get_text())

top100m
# Out:
# ['1.\xa02001: A Space Odyssey (1968)',
#  '2.\xa0The Godfather (1972)',
#  '3.\xa0Citizen Kane (1941)',
#  '4.\xa0Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)',
#  '5.\xa0Raiders of the Lost Ark (1981)',
#  '6.\xa0La Dolce Vita (1960)',
#  '7.\xa0Seven Samurai (1954)',
#  '8.\xa0In the Mood for Love (2000)',
#  '9.\xa0There Will Be Blood (2007)',
#  '10.\xa0Singin’ in the Rain (1952)',
#  '11.\xa0Goodfellas (1990)',
#  '12.\xa0North by Northwest (1959)',
#  '13.\xa0Mulholland Drive (2001)',
#  '14.\xa0Bicycle Thieves (1948)',
#  '15.\xa0The Dark Knight (2008)',
#  '16.\xa0City Lights (1931)',
#  '17.\xa0Grand Illusion (1937)',
#  '18.\xa0His Girl Friday (1940)',
#  '19.\xa0The Red Shoes (1948)',
#  '20.\xa0Vertigo (1958)',
#  '21.\xa0Beau Travail (1999)',
#  '22.\xa0The Searchers (1956)',
#  '23.\xa0Persona (1966)',
#  '24.\xa0Do the Right Thing (1989)',
#  '25.\xa0Rashomon (1950)',
#  '26.\xa0The Rules of the Game (1939)',
#  '27.\xa0Jaws (1975)',
#  '28.\xa0Double Indemnity (1944)',
#  '29.\xa0The 400 Blows (1959)',
#  '30.\xa0Star Wars (1977)',
#  '31.\xa0The Passion of Joan of Arc (1928)',
#  '32.\xa0Once Upon a Time in the West (1968)',
#  '33.\xa0Alien (1979)',
#  '34.\xa0Tokyo Story (1951)',
#  '35.\xa0Pulp Fiction (1994)',
#  '36.\xa0The Truman Show (1998)',
#  '37.\xa0Lawrence of Arabia (1962)',
#  '38.\xa0Psycho (1960)',
#  '39.\xa0Sansho the Bailiff (1954)',
#  '40.\xa0Andrei Rublev (1966)',
#  '41.\xa0The Umbrellas of Cherbourg (1964)',
#  '42.\xa0Chinatown (1974)',
#  '43.\xa0The Seventh Seal (1957)',
#  '44.\xa0Lost in Translation (2003)',
#  '45.\xa0Taxi Driver (1976)',
#  '46.\xa0Spirited Away (2001)',
#  '47.\xa0Night of the Living Dead (1968)',
#  '48.\xa0Battleship Potemkin (1925)',
#  '49.\xa0Modern Times (1936)',
#  '50.\xa0Breathless (1960)',
#  '51.\xa0Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#  '52.\xa0M (1931)',
#  '53.\xa0Blade Runner (1982)',
#  '54.\xa0The Bitter Tears of Petra von Kant (1972)',
#  '55.\xa0Rome, Open City (1945)',
#  '56.\xa0Nosferatu (1922)',
#  '57.\xa0Airplane! (1980)',
#  '58.\xa0Under the Skin (2013)',
#  '59.\xa0Mad Max: Fury Road (2015)',
#  '60.\xa0Apocalypse Now (1979)',
#  '61.\xa0Brokeback Mountain (2005)',
#  '62.\xa0Duck Soup (1933)',
#  '63.\xa0The Blair Witch Project (1999)',
#  '64.\xa0All the President’s Men (1976)',
#  '65.\xa0The Apu trilogy (1955, 1956, 1959)',
#  '66.\xa0The General (1926)',
#  '67.\xa0Eternal Sunshine of the Spotless Mind (2004)',
#  '68.\xa0The Texas Chain Saw Massacre (1974)',
#  '69.\xa0Come and See (1985)',
#  '70.\xa0Heat (1995)',
#  '71.\xa0The Shining (1980)',
#  '72.\xa0Toy Story (1995)',
#  '73.\xa0Killer of Sheep (1977)',
#  '74.\xa0A Woman Under the Influence (1974)',
#  '75.\xa0Annie Hall (1977)',
#  '76.\xa0Some Like It Hot (1959)',
#  '77.\xa0Metropolis (1927)',
#  '78.\xa0The Maltese Falcon (1941)',
#  '79.\xa0This Is Spinal Tap (1984)',
#  '80.\xa0It Happened One Night (1934)',
#  '81.\xa0Die Hard (1988)',
#  '82.\xa0The Conformist (1970)',
#  '83.\xa0The Thing (1982)',
#  '84.\xa0Daughters of the Dust (1991)',
#  '85.\xa0Barry Lyndon (1975)',
#  '86.\xa0Raging Bull (1980)',
#  '87.\xa0Seven (1995)',
#  '88.\xa0Aguirre, the Wrath of God (1972)',
#  '89.\xa0The Battle of Algiers (1966)',
#  '90.\xa0No Country for Old Men (2007)',
#  '91.\xa0Women on the Verge of a Nervous Breakdown (1988)',
#  '92.\xa0The Discreet Charm of the Bourgeoisie (1972)',
#  '93.\xa0Paths of Glory (1957)',
#  '94.\xa0Secrets & Lies (1996)',
#  '95.\xa0Sweet Smell of Success (1957)',
#  '96.\xa0The Cabinet of Dr. Caligari (1920)',
#  '97.\xa0Nashville (1975)',
#  '98.\xa0Don’t Look Now (1973)',
#  '99.\xa0Bonnie and Clyde (1967)',
#  '100.\xa0Get Out (2017)',
#  'Check out the best movies of all time as chosen by actors']

# %%
top100m.pop()
# Out:
# 'Check out the best movies of all time as chosen by actors'

# %%
best_movies = pd.DataFrame({"movie_title":top100m})

# %%
best_movies
# Out:
#                                           movie_title
# 0                     1. 2001: A Space Odyssey (1968)
# 1                             2. The Godfather (1972)
# 2                              3. Citizen Kane (1941)
# 3   4. Jeanne Dielman, 23, Quai du Commerce, 1080 ...
# 4                   5. Raiders of the Lost Ark (1981)
# ..                                                ...
# 95             96. The Cabinet of Dr. Caligari (1920)
# 96                               97. Nashville (1975)
# 97                          98. Don’t Look Now (1973)
# 98                        99. Bonnie and Clyde (1967)
# 99                                100. Get Out (2017)
#
# [100 rows x 1 columns]

# %% [markdown]
# ### Scraping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# 2. find url and store it in a variable
url = "https://gutenberg.org/ebooks/search/?sort_order=downloads"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")
# 4.2. check that the html code looks like it should
soup
# Out:
# <!DOCTYPE html>
#
# <!--
#
# DON'T USE THIS PAGE FOR SCRAPING.
#
# Seriously. You'll only get your IP blocked.
#
# Download https://www.gutenberg.org/feeds/catalog.rdf.bz2 instead,
# which contains *all* Project Gutenberg metadata in one RDF/XML file.
#
# --><html lang="en">
# <head>
# <style>
# .icon   { background: transparent url(/pics/sprite.png) 0 0 no-repeat; }
# .page_content a.subtle_link:link {color:currentColor; text-decoration: none;}
# .page_content a.subtle_link:hover {color:#003366}
# </style>
# <link href="/gutenberg/pg-desktop-one.css" rel="stylesheet" type="text/css"/>
# <link href="/gutenberg/new_nav.css" rel="stylesheet" type="text/css"/>
# <link href="/gutenberg/style.css" rel="stylesheet" type="text/css"/>
# <script>//
# var canonical_url   = "http://www.gutenberg.org/ebooks/search/?sort_order=downloads";
# var lang            = "en";
# var msg_load_more   = "Load More Results…";
# var page_mode       = "screen";
# var dialog_title    = "";
# var dialog_message  = "";
# //</script>
# <script src="/js/pg-two.js"></script>
# <link href="/gutenberg/favicon.ico" rel="shortcut icon"/>
# <link href="http://www.gutenberg.org/ebooks/search/?sort_order=downloads" rel="canonical"/>
# <link href="https://www.gutenberg.org/catalog/osd-books.xml" rel="search" title="Search Project Gutenberg" type="application/opensearchdescription+xml"/>
# <link href="/ebooks/search.opds/?sort_order=downloads" rel="alternate nofollow" title="OPDS feed" type="application/atom+xml;profile=opds-catalog"/>
# <link href="/gutenberg/apple-icon.png" rel="apple-touch-icon"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/css" http-equiv="default-style"/>
# <meta content="All Books (sorted by popularity)" name="title"/>
# <meta content="Project Gutenberg offers 72,857 free eBooks for Kindle, iPad, Nook, Android, and iPhone." name="description"/>
# <meta content="ebook, ebooks, free ebooks, free books, book, books, audio books" name="keywords"/>
# <meta content="public" name="classification"/>
# <meta content="All Books (sorted by popularity)" property="og:title"/>
# <meta content="Project Gutenberg offers 72,857 free eBooks for Kindle, iPad, Nook, Android, and iPhone." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="http://www.gutenberg.org/pics/logo-144x144.png" property="og:image"/>
# <meta content="http://www.gutenberg.org/ebooks/search/?sort_order=downloads" property="og:url"/>
# <meta content="Project Gutenberg" property="og:site_name"/>
# <meta content="115319388529183" property="fb:app_id"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@gutenberg_new" name="twitter:site"/>
# <meta content="http://www.gutenberg.org/pics/logo-144x144.png" name="twitter:image"/>
# <meta content="book cover image" name="twitter:image:alt"/>
# <title>All Books (sorted by popularity) - Project Gutenberg</title>
# <link href="/ebooks/search/" rel="self" title="This Page"/>
# <link href="/ebooks/search/?start_index=26" rel="next" title="Next Page"/>
# <meta content="26" name="totalResults"/>
# <meta content="1" name="startIndex"/>
# <meta content="25" name="itemsPerPage"/>
# </head>
# <body>
# <div class="noprint" id="mw-head-dummy"></div>
# <div class="page_content" id="content">
# <div class="header">
# <h1><span class="icon icon_"></span>All Books (sorted by popularity)</h1>
# </div>
# <div class="body">
# <div>
# <ul class="results">
# <li class="grayed navlink">
# <a accesskey="0" class="link" href="/ebooks/search/?sort_order=title">
# <span class="cell leftcell without-cover">
# <span class="icon-wrapper">
# <span class="icon icon_alpha"></span>
# </span>
# </span>
# <span class="cell content">
# <span class="title">Sort Alphabetically by Title</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="grayed navlink">
# <a accesskey="1" class="link" href="/ebooks/search/?sort_order=release_date">
# <span class="cell leftcell without-cover">
# <span class="icon-wrapper">
# <span class="icon icon_date"></span>
# </span>
# </span>
# <span class="cell content">
# <span class="title">Sort by Release Date</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="statusline">
# <div class="padded">
# <span>Displaying results 1–25</span>
# <span class="links">
# |
# <a accesskey="+" href="/ebooks/search/?sort_order=downloads&amp;start_index=26" title="Go to the next page of results.">Next</a>
# </span>
# </div>
# </li>
# <li class="booklink">
# <a accesskey="3" class="link" href="/ebooks/84">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/84/pg84.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Frankenstein; Or, The Modern Prometheus</span>
# <span class="subtitle">Mary Wollstonecraft Shelley</span>
# <span class="extra">73906 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="4" class="link" href="/ebooks/2701">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/2701/pg2701.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Moby Dick; Or, The Whale</span>
# <span class="subtitle">Herman Melville</span>
# <span class="extra">56756 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="5" class="link" href="/ebooks/1342">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/1342/pg1342.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Pride and Prejudice</span>
# <span class="subtitle">Jane Austen</span>
# <span class="extra">56518 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="6" class="link" href="/ebooks/1513">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/1513/pg1513.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Romeo and Juliet</span>
# <span class="subtitle">William Shakespeare</span>
# <span class="extra">51755 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="7" class="link" href="/ebooks/145">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/145/pg145.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Middlemarch</span>
# <span class="subtitle">George Eliot</span>
# <span class="extra">40455 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="8" class="link" href="/ebooks/2641">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/2641/pg2641.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">A Room with a View</span>
# <span class="subtitle">E. M. Forster</span>
# <span class="extra">38939 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="9" class="link" href="/ebooks/37106">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/37106/pg37106.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Little Women; Or, Meg, Jo, Beth, and Amy</span>
# <span class="subtitle">Louisa May Alcott</span>
# <span class="extra">38178 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="0" class="link" href="/ebooks/100">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/100/pg100.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Complete Works of William Shakespeare</span>
# <span class="subtitle">William Shakespeare</span>
# <span class="extra">37885 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="1" class="link" href="/ebooks/67979">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/67979/pg67979.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Blue Castle: a novel</span>
# <span class="subtitle">L. M. Montgomery</span>
# <span class="extra">34588 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="2" class="link" href="/ebooks/16389">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/16389/pg16389.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Enchanted April</span>
# <span class="subtitle">Elizabeth Von Arnim</span>
# <span class="extra">34263 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="3" class="link" href="/ebooks/6761">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/6761/pg6761.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Adventures of Ferdinand Count Fathom — Complete</span>
# <span class="subtitle">T. Smollett</span>
# <span class="extra">32034 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="4" class="link" href="/ebooks/394">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/394/pg394.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Cranford</span>
# <span class="subtitle">Elizabeth Cleghorn Gaskell</span>
# <span class="extra">31944 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="5" class="link" href="/ebooks/2160">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/2160/pg2160.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Expedition of Humphry Clinker</span>
# <span class="subtitle">T. Smollett</span>
# <span class="extra">31172 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="6" class="link" href="/ebooks/4085">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/4085/pg4085.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Adventures of Roderick Random</span>
# <span class="subtitle">T. Smollett</span>
# <span class="extra">30823 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="7" class="link" href="/ebooks/6593">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/6593/pg6593.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">History of Tom Jones, a Foundling</span>
# <span class="subtitle">Henry Fielding</span>
# <span class="extra">30459 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="8" class="link" href="/ebooks/1259">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/1259/pg1259.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Twenty years after</span>
# <span class="subtitle">Alexandre Dumas and Auguste Maquet</span>
# <span class="extra">30278 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="9" class="link" href="/ebooks/5197">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/5197/pg5197.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">My Life — Volume 1</span>
# <span class="subtitle">Richard Wagner</span>
# <span class="extra">29959 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="0" class="link" href="/ebooks/11">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/11/pg11.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Alice's Adventures in Wonderland</span>
# <span class="subtitle">Lewis Carroll</span>
# <span class="extra">26770 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="1" class="link" href="/ebooks/64317">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/64317/pg64317.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Great Gatsby</span>
# <span class="subtitle">F. Scott Fitzgerald</span>
# <span class="extra">25421 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="2" class="link" href="/ebooks/174">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/174/pg174.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Picture of Dorian Gray</span>
# <span class="subtitle">Oscar Wilde</span>
# <span class="extra">21682 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="3" class="link" href="/ebooks/2542">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/2542/pg2542.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">A Doll's House : a play</span>
# <span class="subtitle">Henrik Ibsen</span>
# <span class="extra">21265 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="4" class="link" href="/ebooks/1952">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/1952/pg1952.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Yellow Wallpaper</span>
# <span class="subtitle">Charlotte Perkins Gilman</span>
# <span class="extra">20252 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="5" class="link" href="/ebooks/844">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/844/pg844.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">The Importance of Being Earnest: A Trivial Comedy for Serious People</span>
# <span class="subtitle">Oscar Wilde</span>
# <span class="extra">19791 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="6" class="link" href="/ebooks/5200">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/5200/pg5200.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">Metamorphosis</span>
# <span class="subtitle">Franz Kafka</span>
# <span class="extra">19576 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="booklink">
# <a accesskey="7" class="link" href="/ebooks/1080">
# <span class="cell leftcell with-cover">
# <img alt="" class="cover-thumb" src="/cache/epub/1080/pg1080.cover.small.jpg"/>
# </span>
# <span class="cell content">
# <span class="title">A Modest Proposal
# </span>
# <span class="subtitle">Jonathan Swift</span>
# <span class="extra">19412 downloads</span>
# </span>
# <span class="hstrut"></span>
# </a>
# </li>
# <li class="statusline">
# <div class="padded">
# Displaying results 1–25
# <span class="links">
# |
# <a accesskey="+" href="/ebooks/search/?sort_order=downloads&amp;start_index=26" title="Go to the next page of results.">Next</a>
# </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer">
# <div>
# <ul>
# <li>
# <a href="/policy/privacy_policy.html" title="Privacy Policy">Privacy policy</a>
# </li>
# <li>
# <a href="/about/" title="About Project Gutenberg">About Project Gutenberg</a>
# </li>
# <li>
# <a href="/policy/terms_of_use.html" title="Terms of Use">Terms of Use</a>
# </li>
# <li>
# <a href="/about/contact_information.html" title="Contact Information">Contact Information</a>
# </li>
# <li><a href="/help/" title="Get Help">Get Help</a></li>
# </ul>
# <a href="https://www.ibiblio.org/" title="Project Gutenberg is hosted by ibiblio">
# <img alt="iBiblio" src="/gutenberg/ibiblio-logo.png"/>
# </a>
# </div>
# </div>
# <nav>
# <!--<div id="main_logo"> -->
# <a class="no-hover" href="/" id="main_logo">
# <img alt="Project Gutenberg" draggable="false" src="/gutenberg/pg-logo-129x80.png"/>
# </a>
# <!--	</div>-->
# <div id="menu">
# <label for="tm" id="toggle-menu">Menu<span class="drop-icon">▾</span></label>
# <input id="tm" type="checkbox"/>
# <ul class="main-menu cf">
# <li>
# <a href="/about/">About
# <span class="drop-icon">▾</span>
# </a>
# <label class="drop-icon" for="sm0" title="Toggle Drop-down">▾</label>
# <input id="sm0" type="checkbox"/>
# <ul class="sub-menu">
# <li><a href="/about/">About Project Gutenberg</a></li>
# <li><a href="/policy/collection_development.html">Collection Development</a></li>
# <li><a href="/about/contact_information.html">Contact Us</a></li>
# <li><a href="/about/background/">History &amp; Philosophy</a></li>
# <li><a href="/policy/permission.html">Permissions &amp; License</a></li>
# <li><a href="/policy/privacy_policy.html">Privacy Policy</a></li>
# <li><a href="/policy/terms_of_use.html">Terms of Use</a></li>
# </ul>
# </li>
# <li>
# <a href="/ebooks/">Search and Browse
# <span class="drop-icon">▾</span>
# </a>
# <label class="drop-icon" for="sm8" title="Toggle Drop-down">▾</label>
# <input id="sm8" type="checkbox"/>
# <ul class="sub-menu">
# <li><a href="/ebooks/">Book Search</a></li>
# <li><a href="/ebooks/bookshelf/">Bookshelves</a></li>
# <li><a href="/browse/scores/top">Frequently Downloaded</a></li>
# <li><a href="/ebooks/offline_catalogs.html">Offline Catalogs</a></li>
# </ul>
# </li>
# <li>
# <a href="/help/">Help
# <span class="drop-icon">▾</span>
# </a>
# <label class="drop-icon" for="sm3" title="Toggle Drop-down">▾</label>
# <input id="sm3" type="checkbox"/>
# <ul class="sub-menu">
# <li><a href="/help/">All help topics →</a></li>
# <li><a href="/help/copyright.html">Copyright Procedures</a></li>
# <li><a href="/help/errata.html">Errata, Fixes and Bug Reports</a></li>
# <li><a href="/help/file_formats.html">File Formats</a></li>
# <li><a href="/help/faq.html">Frequently Asked Questions</a></li>
# <li><a href="/policy/">Policies →</a></li>
# <li><a href="/help/public_domain_ebook_submission.html">Public Domain eBook Submission</a></li>
# <li><a href="/help/submitting_your_own_work.html">Submitting Your Own Work</a></li>
# <li><a href="/help/mobile.html">Tablets, Phones and eReaders</a></li>
# <li><a href="/attic/">The Attic →</a></li>
# </ul>
# </li>
# <li><a href="/donate/">Donate</a></li>
# </ul>
# </div>
# <div class="donate">
# <div class="searchbox">
# <form accept-charset="utf-8" action="/ebooks/search/" class="searchbox" enctype="multipart/form-data" method="get">
# <input class="searchInput" id="menu-book-search" maxlength="80" name="query" placeholder="Quick search" size="20" tabindex="20" title="Quick search" type="text" value=""/>
# <input name="submit_search" style="vertical-align:middle;" type="submit" value="Go!"/>
# </form>
# </div>
# <form action="https://www.paypal.com/cgi-bin/webscr" class="donatelink" method="post" target="new">
# <p><a href="/donate/">Donation</a></p>
# <input name="cmd" type="hidden" value="_s-xclick"/>
# <input name="hosted_button_id" type="hidden" value="XKAL6BZL3YPSN"/>
# <input alt="Donate via PayPal" class="donbtn" name="submit" src="/pics/en_US.gif" type="image"/>
# </form>
# </div>
# </nav>
# </body>
# </html>

# %%
#your code here
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
#
# DON'T USE THIS PAGE FOR SCRAPING.
#
# Seriously. You'll only get your IP blocked.
#
# Download https://www.gutenberg.org/feeds/catalog.rdf.bz2 instead,
# which contains *all* Project Gutenberg metadata in one RDF/XML file.
#
# -->
# <html lang="en">
#  <head>
#   <style>
#    .icon   { background: transparent url(/pics/sprite.png) 0 0 no-repeat; }
# .page_content a.subtle_link:link {color:currentColor; text-decoration: none;}
# .page_content a.subtle_link:hover {color:#003366}
#   </style>
#   <link href="/gutenberg/pg-desktop-one.css" rel="stylesheet" type="text/css"/>
#   <link href="/gutenberg/new_nav.css" rel="stylesheet" type="text/css"/>
#   <link href="/gutenberg/style.css" rel="stylesheet" type="text/css"/>
#   <script>
#    //
# var canonical_url   = "http://www.gutenberg.org/ebooks/search/?sort_order=downloads";
# var lang            = "en";
# var msg_load_more   = "Load More Results…";
# var page_mode       = "screen";
# var dialog_title    = "";
# var dialog_message  = "";
# //
#   </script>
#   <script src="/js/pg-two.js">
#   </script>
#   <link href="/gutenberg/favicon.ico" rel="shortcut icon"/>
#   <link href="http://www.gutenberg.org/ebooks/search/?sort_order=downloads" rel="canonical"/>
#   <link href="https://www.gutenberg.org/catalog/osd-books.xml" rel="search" title="Search Project Gutenberg" type="application/opensearchdescription+xml"/>
#   <link href="/ebooks/search.opds/?sort_order=downloads" rel="alternate nofollow" title="OPDS feed" type="application/atom+xml;profile=opds-catalog"/>
#   <link href="/gutenberg/apple-icon.png" rel="apple-touch-icon"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/css" http-equiv="default-style"/>
#   <meta content="All Books (sorted by popularity)" name="title"/>
#   <meta content="Project Gutenberg offers 72,857 free eBooks for Kindle, iPad, Nook, Android, and iPhone." name="description"/>
#   <meta content="ebook, ebooks, free ebooks, free books, book, books, audio books" name="keywords"/>
#   <meta content="public" name="classification"/>
#   <meta content="All Books (sorted by popularity)" property="og:title"/>
#   <meta content="Project Gutenberg offers 72,857 free eBooks for Kindle, iPad, Nook, Android, and iPhone." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="http://www.gutenberg.org/pics/logo-144x144.png" property="og:image"/>
#   <meta content="http://www.gutenberg.org/ebooks/search/?sort_order=downloads" property="og:url"/>
#   <meta content="Project Gutenberg" property="og:site_name"/>
#   <meta content="115319388529183" property="fb:app_id"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@gutenberg_new" name="twitter:site"/>
#   <meta content="http://www.gutenberg.org/pics/logo-144x144.png" name="twitter:image"/>
#   <meta content="book cover image" name="twitter:image:alt"/>
#   <title>
#    All Books (sorted by popularity) - Project Gutenberg
#   </title>
#   <link href="/ebooks/search/" rel="self" title="This Page"/>
#   <link href="/ebooks/search/?start_index=26" rel="next" title="Next Page"/>
#   <meta content="26" name="totalResults"/>
#   <meta content="1" name="startIndex"/>
#   <meta content="25" name="itemsPerPage"/>
#  </head>
#  <body>
#   <div class="noprint" id="mw-head-dummy">
#   </div>
#   <div class="page_content" id="content">
#    <div class="header">
#     <h1>
#      <span class="icon icon_">
#      </span>
#      All Books (sorted by popularity)
#     </h1>
#    </div>
#    <div class="body">
#     <div>
#      <ul class="results">
#       <li class="grayed navlink">
#        <a accesskey="0" class="link" href="/ebooks/search/?sort_order=title">
#         <span class="cell leftcell without-cover">
#          <span class="icon-wrapper">
#           <span class="icon icon_alpha">
#           </span>
#          </span>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Sort Alphabetically by Title
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="grayed navlink">
#        <a accesskey="1" class="link" href="/ebooks/search/?sort_order=release_date">
#         <span class="cell leftcell without-cover">
#          <span class="icon-wrapper">
#           <span class="icon icon_date">
#           </span>
#          </span>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Sort by Release Date
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="statusline">
#        <div class="padded">
#         <span>
#          Displaying results 1–25
#         </span>
#         <span class="links">
#          |
#          <a accesskey="+" href="/ebooks/search/?sort_order=downloads&amp;start_index=26" title="Go to the next page of results.">
#           Next
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="booklink">
#        <a accesskey="3" class="link" href="/ebooks/84">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/84/pg84.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Frankenstein; Or, The Modern Prometheus
#          </span>
#          <span class="subtitle">
#           Mary Wollstonecraft Shelley
#          </span>
#          <span class="extra">
#           73906 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="4" class="link" href="/ebooks/2701">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/2701/pg2701.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Moby Dick; Or, The Whale
#          </span>
#          <span class="subtitle">
#           Herman Melville
#          </span>
#          <span class="extra">
#           56756 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="5" class="link" href="/ebooks/1342">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/1342/pg1342.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Pride and Prejudice
#          </span>
#          <span class="subtitle">
#           Jane Austen
#          </span>
#          <span class="extra">
#           56518 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="6" class="link" href="/ebooks/1513">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/1513/pg1513.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Romeo and Juliet
#          </span>
#          <span class="subtitle">
#           William Shakespeare
#          </span>
#          <span class="extra">
#           51755 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="7" class="link" href="/ebooks/145">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/145/pg145.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Middlemarch
#          </span>
#          <span class="subtitle">
#           George Eliot
#          </span>
#          <span class="extra">
#           40455 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="8" class="link" href="/ebooks/2641">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/2641/pg2641.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           A Room with a View
#          </span>
#          <span class="subtitle">
#           E. M. Forster
#          </span>
#          <span class="extra">
#           38939 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="9" class="link" href="/ebooks/37106">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/37106/pg37106.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Little Women; Or, Meg, Jo, Beth, and Amy
#          </span>
#          <span class="subtitle">
#           Louisa May Alcott
#          </span>
#          <span class="extra">
#           38178 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="0" class="link" href="/ebooks/100">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/100/pg100.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Complete Works of William Shakespeare
#          </span>
#          <span class="subtitle">
#           William Shakespeare
#          </span>
#          <span class="extra">
#           37885 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="1" class="link" href="/ebooks/67979">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/67979/pg67979.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Blue Castle: a novel
#          </span>
#          <span class="subtitle">
#           L. M. Montgomery
#          </span>
#          <span class="extra">
#           34588 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="2" class="link" href="/ebooks/16389">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/16389/pg16389.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Enchanted April
#          </span>
#          <span class="subtitle">
#           Elizabeth Von Arnim
#          </span>
#          <span class="extra">
#           34263 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="3" class="link" href="/ebooks/6761">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/6761/pg6761.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Adventures of Ferdinand Count Fathom — Complete
#          </span>
#          <span class="subtitle">
#           T. Smollett
#          </span>
#          <span class="extra">
#           32034 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="4" class="link" href="/ebooks/394">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/394/pg394.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Cranford
#          </span>
#          <span class="subtitle">
#           Elizabeth Cleghorn Gaskell
#          </span>
#          <span class="extra">
#           31944 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="5" class="link" href="/ebooks/2160">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/2160/pg2160.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Expedition of Humphry Clinker
#          </span>
#          <span class="subtitle">
#           T. Smollett
#          </span>
#          <span class="extra">
#           31172 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="6" class="link" href="/ebooks/4085">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/4085/pg4085.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Adventures of Roderick Random
#          </span>
#          <span class="subtitle">
#           T. Smollett
#          </span>
#          <span class="extra">
#           30823 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="7" class="link" href="/ebooks/6593">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/6593/pg6593.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           History of Tom Jones, a Foundling
#          </span>
#          <span class="subtitle">
#           Henry Fielding
#          </span>
#          <span class="extra">
#           30459 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="8" class="link" href="/ebooks/1259">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/1259/pg1259.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Twenty years after
#          </span>
#          <span class="subtitle">
#           Alexandre Dumas and Auguste Maquet
#          </span>
#          <span class="extra">
#           30278 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="9" class="link" href="/ebooks/5197">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/5197/pg5197.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           My Life — Volume 1
#          </span>
#          <span class="subtitle">
#           Richard Wagner
#          </span>
#          <span class="extra">
#           29959 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="0" class="link" href="/ebooks/11">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/11/pg11.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Alice's Adventures in Wonderland
#          </span>
#          <span class="subtitle">
#           Lewis Carroll
#          </span>
#          <span class="extra">
#           26770 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="1" class="link" href="/ebooks/64317">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/64317/pg64317.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Great Gatsby
#          </span>
#          <span class="subtitle">
#           F. Scott Fitzgerald
#          </span>
#          <span class="extra">
#           25421 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="2" class="link" href="/ebooks/174">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/174/pg174.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Picture of Dorian Gray
#          </span>
#          <span class="subtitle">
#           Oscar Wilde
#          </span>
#          <span class="extra">
#           21682 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="3" class="link" href="/ebooks/2542">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/2542/pg2542.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           A Doll's House : a play
#          </span>
#          <span class="subtitle">
#           Henrik Ibsen
#          </span>
#          <span class="extra">
#           21265 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="4" class="link" href="/ebooks/1952">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/1952/pg1952.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Yellow Wallpaper
#          </span>
#          <span class="subtitle">
#           Charlotte Perkins Gilman
#          </span>
#          <span class="extra">
#           20252 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="5" class="link" href="/ebooks/844">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/844/pg844.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           The Importance of Being Earnest: A Trivial Comedy for Serious People
#          </span>
#          <span class="subtitle">
#           Oscar Wilde
#          </span>
#          <span class="extra">
#           19791 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="6" class="link" href="/ebooks/5200">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/5200/pg5200.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           Metamorphosis
#          </span>
#          <span class="subtitle">
#           Franz Kafka
#          </span>
#          <span class="extra">
#           19576 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="booklink">
#        <a accesskey="7" class="link" href="/ebooks/1080">
#         <span class="cell leftcell with-cover">
#          <img alt="" class="cover-thumb" src="/cache/epub/1080/pg1080.cover.small.jpg"/>
#         </span>
#         <span class="cell content">
#          <span class="title">
#           A Modest Proposal
#          </span>
#          <span class="subtitle">
#           Jonathan Swift
#          </span>
#          <span class="extra">
#           19412 downloads
#          </span>
#         </span>
#         <span class="hstrut">
#         </span>
#        </a>
#       </li>
#       <li class="statusline">
#        <div class="padded">
#         Displaying results 1–25
#         <span class="links">
#          |
#          <a accesskey="+" href="/ebooks/search/?sort_order=downloads&amp;start_index=26" title="Go to the next page of results.">
#           Next
#          </a>
#         </span>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="footer">
#    <div>
#     <ul>
#      <li>
#       <a href="/policy/privacy_policy.html" title="Privacy Policy">
#        Privacy policy
#       </a>
#      </li>
#      <li>
#       <a href="/about/" title="About Project Gutenberg">
#        About Project Gutenberg
#       </a>
#      </li>
#      <li>
#       <a href="/policy/terms_of_use.html" title="Terms of Use">
#        Terms of Use
#       </a>
#      </li>
#      <li>
#       <a href="/about/contact_information.html" title="Contact Information">
#        Contact Information
#       </a>
#      </li>
#      <li>
#       <a href="/help/" title="Get Help">
#        Get Help
#       </a>
#      </li>
#     </ul>
#     <a href="https://www.ibiblio.org/" title="Project Gutenberg is hosted by ibiblio">
#      <img alt="iBiblio" src="/gutenberg/ibiblio-logo.png"/>
#     </a>
#    </div>
#   </div>
#   <nav>
#    <!--<div id="main_logo"> -->
#    <a class="no-hover" href="/" id="main_logo">
#     <img alt="Project Gutenberg" draggable="false" src="/gutenberg/pg-logo-129x80.png"/>
#    </a>
#    <!--	</div>-->
#    <div id="menu">
#     <label for="tm" id="toggle-menu">
#      Menu
#      <span class="drop-icon">
#       ▾
#      </span>
#     </label>
#     <input id="tm" type="checkbox"/>
#     <ul class="main-menu cf">
#      <li>
#       <a href="/about/">
#        About
#        <span class="drop-icon">
#         ▾
#        </span>
#       </a>
#       <label class="drop-icon" for="sm0" title="Toggle Drop-down">
#        ▾
#       </label>
#       <input id="sm0" type="checkbox"/>
#       <ul class="sub-menu">
#        <li>
#         <a href="/about/">
#          About Project Gutenberg
#         </a>
#        </li>
#        <li>
#         <a href="/policy/collection_development.html">
#          Collection Development
#         </a>
#        </li>
#        <li>
#         <a href="/about/contact_information.html">
#          Contact Us
#         </a>
#        </li>
#        <li>
#         <a href="/about/background/">
#          History &amp; Philosophy
#         </a>
#        </li>
#        <li>
#         <a href="/policy/permission.html">
#          Permissions &amp; License
#         </a>
#        </li>
#        <li>
#         <a href="/policy/privacy_policy.html">
#          Privacy Policy
#         </a>
#        </li>
#        <li>
#         <a href="/policy/terms_of_use.html">
#          Terms of Use
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/ebooks/">
#        Search and Browse
#        <span class="drop-icon">
#         ▾
#        </span>
#       </a>
#       <label class="drop-icon" for="sm8" title="Toggle Drop-down">
#        ▾
#       </label>
#       <input id="sm8" type="checkbox"/>
#       <ul class="sub-menu">
#        <li>
#         <a href="/ebooks/">
#          Book Search
#         </a>
#        </li>
#        <li>
#         <a href="/ebooks/bookshelf/">
#          Bookshelves
#         </a>
#        </li>
#        <li>
#         <a href="/browse/scores/top">
#          Frequently Downloaded
#         </a>
#        </li>
#        <li>
#         <a href="/ebooks/offline_catalogs.html">
#          Offline Catalogs
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/help/">
#        Help
#        <span class="drop-icon">
#         ▾
#        </span>
#       </a>
#       <label class="drop-icon" for="sm3" title="Toggle Drop-down">
#        ▾
#       </label>
#       <input id="sm3" type="checkbox"/>
#       <ul class="sub-menu">
#        <li>
#         <a href="/help/">
#          All help topics →
#         </a>
#        </li>
#        <li>
#         <a href="/help/copyright.html">
#          Copyright Procedures
#         </a>
#        </li>
#        <li>
#         <a href="/help/errata.html">
#          Errata, Fixes and Bug Reports
#         </a>
#        </li>
#        <li>
#         <a href="/help/file_formats.html">
#          File Formats
#         </a>
#        </li>
#        <li>
#         <a href="/help/faq.html">
#          Frequently Asked Questions
#         </a>
#        </li>
#        <li>
#         <a href="/policy/">
#          Policies →
#         </a>
#        </li>
#        <li>
#         <a href="/help/public_domain_ebook_submission.html">
#          Public Domain eBook Submission
#         </a>
#        </li>
#        <li>
#         <a href="/help/submitting_your_own_work.html">
#          Submitting Your Own Work
#         </a>
#        </li>
#        <li>
#         <a href="/help/mobile.html">
#          Tablets, Phones and eReaders
#         </a>
#        </li>
#        <li>
#         <a href="/attic/">
#          The Attic →
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a href="/donate/">
#        Donate
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="donate">
#     <div class="searchbox">
#      <form accept-charset="utf-8" action="/ebooks/search/" class="searchbox" enctype="multipart/form-data" method="get">
#       <input class="searchInput" id="menu-book-search" maxlength="80" name="query" placeholder="Quick search" size="20" tabindex="20" title="Quick search" type="text" value=""/>
#       <input name="submit_search" style="vertical-align:middle;" type="submit" value="Go!"/>
#      </form>
#     </div>
#     <form action="https://www.paypal.com/cgi-bin/webscr" class="donatelink" method="post" target="new">
#      <p>
#       <a href="/donate/">
#        Donation
#       </a>
#      </p>
#      <input name="cmd" type="hidden" value="_s-xclick"/>
#      <input name="hosted_button_id" type="hidden" value="XKAL6BZL3YPSN"/>
#      <input alt="Donate via PayPal" class="donbtn" name="submit" src="/pics/en_US.gif" type="image"/>
#     </form>
#    </div>
#   </nav>
#  </body>
# </html>

# %%
ebooks = []
for title in soup.select("li.booklink span.title"):
    ebooks.append(title.get_text())

ebooks
# Out:
# ['Frankenstein; Or, The Modern Prometheus',
#  'Moby Dick; Or, The Whale',
#  'Pride and Prejudice',
#  'Romeo and Juliet',
#  'Middlemarch',
#  'A Room with a View',
#  'Little Women; Or, Meg, Jo, Beth, and Amy',
#  'The Complete Works of William Shakespeare',
#  'The Blue Castle: a novel',
#  'The Enchanted April',
#  'The Adventures of Ferdinand Count Fathom — Complete',
#  'Cranford',
#  'The Expedition of Humphry Clinker',
#  'The Adventures of Roderick Random',
#  'History of Tom Jones, a Foundling',
#  'Twenty years after',
#  'My Life — Volume 1',
#  "Alice's Adventures in Wonderland",
#  'The Great Gatsby',
#  'The Picture of Dorian Gray',
#  "A Doll's House : a play",
#  'The Yellow Wallpaper',
#  'The Importance of Being Earnest: A Trivial Comedy for Serious People',
#  'Metamorphosis',
#  'A Modest Proposal\r']

# %%
best_ebooks = pd.DataFrame({"ebook_title":ebooks})
best_ebooks
# Out:
#                                           ebook_title
# 0             Frankenstein; Or, The Modern Prometheus
# 1                            Moby Dick; Or, The Whale
# 2                                 Pride and Prejudice
# 3                                    Romeo and Juliet
# 4                                         Middlemarch
# 5                                  A Room with a View
# 6            Little Women; Or, Meg, Jo, Beth, and Amy
# 7           The Complete Works of William Shakespeare
# 8                            The Blue Castle: a novel
# 9                                 The Enchanted April
# 10  The Adventures of Ferdinand Count Fathom — Com...
# 11                                           Cranford
# 12                  The Expedition of Humphry Clinker
# 13                  The Adventures of Roderick Random
# 14                  History of Tom Jones, a Foundling
# 15                                 Twenty years after
# 16                                 My Life — Volume 1
# 17                   Alice's Adventures in Wonderland
# 18                                   The Great Gatsby
# 19                         The Picture of Dorian Gray
# 20                            A Doll's House : a play
# 21                               The Yellow Wallpaper
# 22  The Importance of Being Earnest: A Trivial Com...
# 23                                      Metamorphosis
# 24                                A Modest Proposal\r

# %%
authors = []
for a in soup.select("li.booklink span.subtitle"):
    authors.append(a.get_text())

authors
# Out:
# ['Mary Wollstonecraft Shelley',
#  'Herman Melville',
#  'Jane Austen',
#  'William Shakespeare',
#  'George Eliot',
#  'E. M. Forster',
#  'Louisa May Alcott',
#  'William Shakespeare',
#  'L. M. Montgomery',
#  'Elizabeth Von Arnim',
#  'T. Smollett',
#  'Elizabeth Cleghorn Gaskell',
#  'T. Smollett',
#  'T. Smollett',
#  'Henry Fielding',
#  'Alexandre Dumas and Auguste Maquet',
#  'Richard Wagner',
#  'Lewis Carroll',
#  'F. Scott Fitzgerald',
#  'Oscar Wilde',
#  'Henrik Ibsen',
#  'Charlotte Perkins Gilman',
#  'Oscar Wilde',
#  'Franz Kafka',
#  'Jonathan Swift']

# %%
books_authors = pd.DataFrame({"author":authors})
books_authors
# Out:
#                                 author
# 0          Mary Wollstonecraft Shelley
# 1                      Herman Melville
# 2                          Jane Austen
# 3                  William Shakespeare
# 4                         George Eliot
# 5                        E. M. Forster
# 6                    Louisa May Alcott
# 7                  William Shakespeare
# 8                     L. M. Montgomery
# 9                  Elizabeth Von Arnim
# 10                         T. Smollett
# 11          Elizabeth Cleghorn Gaskell
# 12                         T. Smollett
# 13                         T. Smollett
# 14                      Henry Fielding
# 15  Alexandre Dumas and Auguste Maquet
# 16                      Richard Wagner
# 17                       Lewis Carroll
# 18                 F. Scott Fitzgerald
# 19                         Oscar Wilde
# 20                        Henrik Ibsen
# 21            Charlotte Perkins Gilman
# 22                         Oscar Wilde
# 23                         Franz Kafka
# 24                      Jonathan Swift

# %%
online_books = pd.concat([best_ebooks, books_authors], axis=1)
online_books
# Out:
#                                           ebook_title  \
# 0             Frankenstein; Or, The Modern Prometheus
# 1                            Moby Dick; Or, The Whale
# 2                                 Pride and Prejudice
# 3                                    Romeo and Juliet
# 4                                         Middlemarch
# 5                                  A Room with a View
# 6            Little Women; Or, Meg, Jo, Beth, and Amy
# 7           The Complete Works of William Shakespeare
# 8                            The Blue Castle: a novel
# 9                                 The Enchanted April
# 10  The Adventures of Ferdinand Count Fathom — Com...
# 11                                           Cranford
# 12                  The Expedition of Humphry Clinker
# 13                  The Adventures of Roderick Random
# 14                  History of Tom Jones, a Foundling
# 15                                 Twenty years after
# 16                                 My Life — Volume 1
# 17                   Alice's Adventures in Wonderland
# 18                                   The Great Gatsby
# 19                         The Picture of Dorian Gray
# 20                            A Doll's House : a play
# 21                               The Yellow Wallpaper
# 22  The Importance of Being Earnest: A Trivial Com...
# 23                                      Metamorphosis
# 24                                A Modest Proposal\r
#
#                                 author
# 0          Mary Wollstonecraft Shelley
# 1                      Herman Melville
# 2                          Jane Austen
# 3                  William Shakespeare
# 4                         George Eliot
# 5                        E. M. Forster
# 6                    Louisa May Alcott
# 7                  William Shakespeare
# 8                     L. M. Montgomery
# 9                  Elizabeth Von Arnim
# 10                         T. Smollett
# 11          Elizabeth Cleghorn Gaskell
# 12                         T. Smollett
# 13                         T. Smollett
# 14                      Henry Fielding
# 15  Alexandre Dumas and Auguste Maquet
# 16                      Richard Wagner
# 17                       Lewis Carroll
# 18                 F. Scott Fitzgerald
# 19                         Oscar Wilde
# 20                        Henrik Ibsen
# 21            Charlotte Perkins Gilman
# 22                         Oscar Wilde
# 23                         Franz Kafka
# 24                      Jonathan Swift

# %%
'''best_books_df = pd.DataFrame({"books":ebooks, "author":authors})
best_books_df'''

# %%
online_books.shape
# Out:
# (25, 2)

# %% [markdown]
# ### Billboard

# %%
url ="https://www.billboard.com/charts/hot-100/"
response = requests.get(url)
soup = BeautifulSoup(response.content)

# %%
hiss[0].get_text(strip=True)
# Out:
# 'Hiss'

# %%
songs = []

for s in soup.select("h3.c-title.a-no-trucate"):
    songs.append(s.get_text(strip=True))

songs
# Out:
# ['Hiss',
#  'Lovin On Me',
#  'Cruel Summer',
#  'Lose Control',
#  'Greedy',
#  'I Remember Everything',
#  'Agora Hills',
#  'Beautiful Things',
#  'Redrum',
#  'Snooze',
#  'Water',
#  'Stick Season',
#  'Paint The Town Red',
#  'Last Night',
#  "Thinkin' Bout Me",
#  'Facts',
#  'Yes, And?',
#  'Never Lose Me',
#  'Selfish',
#  'Fast Car',
#  "Is It Over Now? (Taylor's Version) [From The Vault]",
#  'La Diabla',
#  'Big Foot',
#  'Spin You Around (1/24)',
#  'White Horse',
#  'Everybody',
#  'Pretty Little Poison',
#  'Made For Me',
#  'Rich Baby Daddy',
#  'Houdini',
#  'What Was I Made For?',
#  'Flowers',
#  'Where The Wild Things Are',
#  'Igual Que Un Angel',
#  'Wild Ones',
#  'Feather',
#  'Think U The Shit (Fart)',
#  'Lil Boo Thang',
#  'Fukumean',
#  'FTCU',
#  'Need A Favor',
#  'Good Good',
#  'Dance The Night',
#  'The Painter',
#  'First Person Shooter',
#  'Vampire',
#  'Surround Sound',
#  'World On Fire',
#  'Save Me',
#  'On My Mama',
#  'Truck Bed',
#  'My Love Mine All Mine',
#  'La Victima',
#  'Exes',
#  'Strangers',
#  'Nee-nah',
#  'Murder On The Dancefloor',
#  'One Of The Girls',
#  'Act II: Date @ 8',
#  'Burn It Down',
#  'You Broke My Heart',
#  'Harley Quinn',
#  'Bellakeo',
#  'Man Made A Bar',
#  'IDGAF',
#  "Different 'Round Here",
#  'Monaco',
#  '500lbs',
#  'Soak City',
#  'Prove It',
#  'N.H.I.E.',
#  'All Of Me',
#  'I Can Feel It',
#  'Praise Jah In The Moonlight',
#  '23',
#  "Should've Wore A Bonnet",
#  'Home',
#  'Mmhmm',
#  'One Call',
#  "We Don't Fight Anymore",
#  'FE!N',
#  'Que Onda',
#  'Perro Negro',
#  "Mamaw's House",
#  'Y Lloro',
#  'Oklahoma Smokeshow',
#  'Coal',
#  'No Caller ID',
#  'Creek Will Rise',
#  'Wondering Why',
#  'First Love',
#  'La Intencion',
#  '02.02.99',
#  'Standing Next To You',
#  'Sneaky',
#  'Wildflowers And Wild Horses',
#  'Northern Attitude',
#  'All I Need Is You',
#  'My Eyes',
#  'Worth It']

# %%
artist=[]

for a in soup.select("span.c-label.a-no-trucate"):
    artist.append(a.get_text(strip=True))

artist
# Out:
# ['Megan Thee Stallion',
#  'Jack Harlow',
#  'Taylor Swift',
#  'Teddy Swims',
#  'Tate McRae',
#  'Zach Bryan Featuring Kacey Musgraves',
#  'Doja Cat',
#  'Benson Boone',
#  '21 Savage',
#  'SZA',
#  'Tyla',
#  'Noah Kahan',
#  'Doja Cat',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Tom MacDonald X Ben Shapiro',
#  'Ariana Grande',
#  'Flo Milli',
#  'Justin Timberlake',
#  'Luke Combs',
#  'Taylor Swift',
#  'Xavi',
#  'Nicki Minaj',
#  'Morgan Wallen',
#  'Chris Stapleton',
#  'Nicki Minaj Featuring Lil Uzi Vert',
#  'Warren Zeiders',
#  'Muni Long',
#  'Drake Featuring Sexyy Red & SZA',
#  'Dua Lipa',
#  'Billie Eilish',
#  'Miley Cyrus',
#  'Luke Combs',
#  'Kali Uchis & Peso Pluma',
#  'Jessie Murph & Jelly Roll',
#  'Sabrina Carpenter',
#  'Ice Spice',
#  'Paul Russell',
#  'Gunna',
#  'Nicki Minaj',
#  'Jelly Roll',
#  'Usher, Summer Walker & 21 Savage',
#  'Dua Lipa',
#  'Cody Johnson',
#  'Drake Featuring J. Cole',
#  'Olivia Rodrigo',
#  'JID Featuring 21 Savage & Baby Tate',
#  'Nate Smith',
#  'Jelly Roll With Lainey Wilson',
#  'Victoria Monet',
#  'HARDY',
#  'Mitski',
#  'Xavi',
#  'Tate McRae',
#  'Kenya Grace',
#  '21 Savage, Travis Scott & Metro Boomin',
#  'Sophie Ellis-Bextor',
#  'The Weeknd, Jennie & Lily Rose Depp',
#  '4Batz',
#  'Parker McCollum',
#  'Drake',
#  'Fuerza Regida & Marshmello',
#  'Peso Pluma & Anitta',
#  'Morgan Wallen Featuring Eric Church',
#  'Drake Featuring Yeat',
#  'Riley Green Featuring Luke Combs',
#  'Bad Bunny',
#  'Lil Tecca',
#  '310babii',
#  '21 Savage & Summer Walker',
#  '21 Savage & Doja Cat',
#  '21 Savage',
#  'Kane Brown',
#  'YG Marley',
#  'Chayce Beckham',
#  '21 Savage & Brent Faiyaz',
#  'Good Neighbours',
#  'BigXthaPlug',
#  'Rich Amiri',
#  'Carly Pearce Featuring Chris Stapleton',
#  'Travis Scott Featuring Playboi Carti',
#  'Calle 24 x Chino Pacas x Fuerza Regida',
#  'Bad Bunny & Feid',
#  'Thomas Rhett Featuring Morgan Wallen',
#  'Junior H',
#  'Zach Bryan',
#  'Dylan Gossett',
#  'Megan Moroney',
#  'Conner Smith',
#  'The Red Clay Strays',
#  'Oscar Ortiz X Edgardo Nunez',
#  'Christian Nodal & Peso Pluma',
#  'That Mexican OT',
#  'Jung Kook',
#  '21 Savage',
#  'Lainey Wilson',
#  'Noah Kahan With Hozier',
#  'Chris Janson',
#  'Travis Scott',
#  'Offset & Don Toliver']

# %%
billboard_100 = pd.DataFrame({"song":songs, "artist":artist})
billboard_100
# Out:
#                            song                  artist
# 0                          Hiss     Megan Thee Stallion
# 1                   Lovin On Me             Jack Harlow
# 2                  Cruel Summer            Taylor Swift
# 3                  Lose Control             Teddy Swims
# 4                        Greedy              Tate McRae
# ..                          ...                     ...
# 95  Wildflowers And Wild Horses           Lainey Wilson
# 96            Northern Attitude  Noah Kahan With Hozier
# 97            All I Need Is You            Chris Janson
# 98                      My Eyes            Travis Scott
# 99                     Worth It    Offset & Don Toliver
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Cleaning the data

# %%
# your code here
